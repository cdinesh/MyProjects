# %%
import urllib.parse
import random
import oauthlib
from requests_oauthlib import OAuth1Session
import credentials_History
import twitter_settings  
import imp 
imp.reload(twitter_settings)
imp.reload(credentials_History)
from twitter_settings import *
import re
import tweepy
import mysql.connector
import pandas as pd
import numpy as np
#from textblob import TextBlob
from nltk.sentiment.vader import SentimentIntensityAnalyzer
import json
import datetime
from datetime import date, timedelta
import random
import time
from datetime import datetime, timezone
import pytz

# %%
def clean_tweet(tweet): 
     
    ##Use sumple regex statemnents to clean tweet text by removing links and special characters
    
    tweet_text= ' '.join(re.sub("(RT @[\w_]+:)|(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)", " ", tweet).split()) 
    tweet_text = re.sub(r'(.)\1{2,}',r'\1\1',tweet_text)
    return tweet_text

def deEmojify_tweet(text):
    
    ##Strip all non-ASCII characters to remove emoji characters
    
    if text:
        return text.encode('ascii', 'ignore').decode('ascii')
    else:
        return None

# %%
mydb = mysql.connector.connect(
    host="localhost",
    user="root",
    password="*******",
    database="TwitterDB",
    auth_plugin='mysql_native_password',
    charset='utf8'
    
)
if mydb.is_connected():
    mycursor = mydb.cursor()
    mycursor.execute("SELECT COUNT(*) FROM information_schema.tables where table_name='{0}'".
                     format(twitter_settings.HISTORY_TABLE_NAME))
if mycursor.fetchone()[0] != 1:
    mycursor.execute("CREATE TABLE {} ({})".format(twitter_settings.HISTORY_TABLE_NAME, twitter_settings.HISTORY_TABLE_ATTRIBUTES))
    mydb.commit()
    mycursor.close()

# %%
def save_tweets(status,identifier):
    try:
        print("Inside tweet function")
        #print(len(tweets_list))
        
        print("Tweet started")

        print('Retweet status: {0}'.format(status["retweeted"]))
        print('Original tweet: {0}'.format(status["text"]))

        if status["retweeted"]:
            ## for now avoid retweeted info
            return True

        #Extract attributes of each tweet
        id_str=status["id_str"]
        created_at=status["created_at"]
        print("created at: {0}".format(created_at))
        created_at=datetime.strptime(status["created_at"], '%a %b %d %H:%M:%S %z %Y').replace(
            tzinfo=timezone.utc).astimezone(pytz.timezone('US/Eastern')).strftime('%Y-%m-%d %H:%M:%S')
        print("created at: {0}".format(created_at))
        original_text=status["text"]
        text=deEmojify_tweet(status["text"])
        text=clean_tweet(text)

        print('Clean tweet: {0}'.format(text))

        ## use Vader to check sentiment of text
        ########################################
        analyser = SentimentIntensityAnalyzer()

        score = analyser.polarity_scores(status["text"])
        print("{:-<40} {}".format(text, str(score)))

        if score['compound']>=0.05: #positive
            polarity = 1
        elif (score['compound']>-0.05) & (score['compound']<0.05): #neutral
            polarity = 0
        elif score['compound']<=-0.05: #negative
            polarity = -1

        compound_score=score['compound']
        positive_score=score['pos']
        negative_score=score['neg']
        neutral_score=score['neu']

        print('polarity: {0}'.format(polarity))

        ## set subjectivity as 0 for Vader
        subjectivity = 0
        ###########################################

        ## use TextBlob to check sentiment of text
        ########################################
    #         sentiment=TextBlob(text).sentiment
    #         polarity=sentiment.polarity
    #         subjectivity=sentiment.subjectivity
        ######################################



        
       
        #usermentions_list = json.dump(user_mentions)
        user_id = status["user"]["id_str"]
        user_name = status["user"]["name"]
        user_screen_name = status["user"]["screen_name"]
        print('userId: {0}, userName: {1}, userScreenName: {2}'.format(user_id,user_name,user_screen_name))
        user_created_at = status["user"]["created_at"]
        user_location=deEmojify_tweet(status["user"]["location"])
        user_description=deEmojify_tweet(status["user"]["description"])

        user_friends_count = status["user"]["friends_count"]
        user_followers_count=status["user"]["followers_count"]
        user_following = status["user"]["following"]
        print('user follower count: {0}, userFollowing: {1}'.format(user_followers_count,user_following))
        print('user friends count: {0}'.format(user_friends_count))

        #------------------------------------------
        tweetFound=False
        track_val = ''
        tweet_found_count = 0

        netflix_check_list = ['Netflix','netflix']
        netflix_check_set = set(netflix_check_list)
#         appletv_check_list = ['AppleTV','Apple TV','appletv','apple tv']
#         appletv_check_set = set(appletv_check_list)
#         disney_check_list = ['DisneyPlus','Disney+','disneyplus','disney+','disney','Disney','Disneyplus']
#         disney_check_set = set(disney_check_list)
#         amazon_check_list = ['Amazon Prime Video','amazon prime video','AmazonPrimeVideo',
#                      'amazonprimevideo','AmazonPrime Video','Amazon Prime','amazon prime','amazon','prime',
#                     'Amazon','Prime']
#         amazon_check_set = set(amazon_check_list)
#     #         hbo_check_list = ['HBOMax','HBO Max','hbomax']
#     #         hbo_check_set = set(hbo_check_list)

        text_set = set(text.split())
        print('text set: {0}'.format(text_set))
#         if amazon_check_set.intersection(text_set):
#             track_val = 'AmazonPrime'
#             tweetFound=True
#             tweet_found_count = tweet_found_count + 1
#         if appletv_check_set.intersection(text_set):
#             track_val = 'AppleTV'
#             tweetFound=True
#             tweet_found_count = tweet_found_count + 1
        print('Identifier: {0}'.format(identifier))
#         if (identifier=='Disney') and (disney_check_set.intersection(text_set)):
#             track_val = 'DisneyPlus'
#             tweetFound=True
#             tweet_found_count = tweet_found_count + 1
        if (identifier=='Netflix') and (netflix_check_set.intersection(text_set)):
            track_val = 'Netflix'
            tweetFound=True
            tweet_found_count = tweet_found_count + 1

        if (tweet_found_count > 1):
            tweetFound = False

        print("tweet found: {0}".format(tweetFound))
        print("Lets begin to record! All the best :)")

        longitude=None
        latitude=None
#         if status["coordinates"]:
#             longitude=status["coordinates"]["coordinates"][0]
#             latitude=status["coordinates"]["coordinates"][1]

            
        print('latitude: {0}  logitude: {1}'.format(latitude,longitude))
        
        retweet_count=status["retweet_count"]
        favorite_count=status["favorite_count"]

        print('retweet count: {0}'.format(retweet_count))
        print('faviourite count: {0}'.format(favorite_count))
        
        hashtags = []   #make an empty list

#         if status["entities"]!=null:
#             print("hashtags: {0}".format(status["entities"]))

        for hashtag in status["entities"]["hashtags"]:    #iterate over the list
            hashtags.append(hashtag["text"])             #append each hashtag to 'hashtags'

        print('hashtags: {0}'.format(str(hashtags)))

        if tweetFound:
            if mydb.is_connected():
                mycursor=mydb.cursor()

                sql = "INSERT IGNORE INTO {} (id_str, created_at, track ,text, original_text, polarity, compound_score, negative_score, positive_score, neutral_score,subjectivity, hashtags,\
                user_created_at, user_id, user_name, user_screen_name,\
                user_location, user_description, user_followers_count, user_friends_count, longitude, latitude, retweet_count, favorite_count) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)".format(twitter_settings.HISTORY_TABLE_NAME)
                val = (id_str, created_at, track_val, text, original_text, polarity, compound_score, negative_score, positive_score, neutral_score ,subjectivity, str(hashtags), user_created_at, user_id, user_name, user_screen_name, user_location, \
                    user_description, user_followers_count, user_friends_count, longitude, latitude, retweet_count, favorite_count)
                mycursor.execute(sql, val)
                mydb.commit()
                mycursor.close()
                
                print("Insert done!")
    except:   
        return False

# %%
class GetTweets:
    def parse_config(self):
        config = {}
      # from file args
        if os.path.exists('data/config.json'):
            with open('data/config.json') as f:
                config.update(json.load(f))
      # should have something now
        return config

    def oauth_req(self, url, http_method="GET", post_body=None,
                  http_headers=None):
        #config = self.parse_config()
        twitter = OAuth1Session(credentials_History.API_KEY,client_secret=credentials_History.API_SECRET_KEY,resource_owner_key=credentials_History.ACCESS_TOKEN,resource_owner_secret=credentials_History.ACCESS_TOKEN_SECRET)
        resp = twitter.request(http_method,url)
        return resp
    
    #start getTwitterData
    def getData(self, keyword, params = {}):
        maxTweets = 1000
        url = 'https://api.twitter.com/1.1/search/tweets.json?'    
        data = {'q': keyword, 'lang': 'en', 'result_type': 'recent', 'count': maxTweets, 'include_entities': 1}
        #Add if additional params are passed
        if params:
            for key, value in params.items():
                data[key] = value
        
        url += urllib.parse.urlencode(data)
        response = self.oauth_req(url)          
        jsonData = json.loads(response.content.decode('UTF-8'))

        if 'errors' in jsonData:
            print("API Error")
            print(jsonData['errors'])
        else:
            return jsonData
    #end    

    def getTwitterData(self, symbol,identifier):
        #tomorrow = datetime.datetime.now()+timedelta(days=+1)
        since_date = datetime.now() - timedelta(days=10)
        until_date = datetime.now() - timedelta(days=3)
        print(until_date)
        until_now = datetime.now() 
        until_future = until_date + timedelta(days=1)
        print(until_now)
        #params = {'since': since_date.strftime("%Y-%m-%d"), 'until': until_date.strftime("%Y-%m-%d")}
        params = {'since': until_date.strftime("%Y-%m-%d"), 'until': until_future.strftime("%Y-%m-%d")}
        jsonData = self.getData(symbol, params)
        tweets = []
        for item in jsonData['statuses']:
            myData = {}
            myData["created_at"] = item["created_at"]
            myData["text"] = item["text"]
            myData["user"] = item["user"]["screen_name"]
            save_tweets(item,identifier)
            tweets.append(myData)
        print(jsonData)
        return tweets
 
 
if __name__ == "__main__":
    a  = GetTweets()
    print(a.getTwitterData('Netflix or netflix','Netflix'))
    #print(a.getTwitterData('DisneyPlus OR Disney+ OR disneyplus OR disney+','Disney'))
# Out:
# 2019-11-30 13:33:57.277101
# 2019-12-03 13:33:57.277213
# Inside tweet function
# Tweet started
# Retweet status: False
# Original tweet: RT @AimanIAbdullah: I Netflix when I have lunch at work.
#
# For many of us, our jobs demand interaction with people/many people whether we li…
# created at: Sat Nov 30 23:58:49 +0000 2019
# created at: 2019-11-30 18:58:49
# Clean tweet: I Netflix when I have lunch at work For many of us our jobs demand interaction with people many people whether we li
# I Netflix when I have lunch at work For many of us our jobs demand interaction with people many people whether we li {'neg': 0.067, 'neu': 0.933, 'pos': 0.0, 'compound': -0.128}
# polarity: -1
# userId: 495700546, userName: Golden Recipe, userScreenName: AisyahSyarip
# user follower count: 422, userFollowing: False
# user friends count: 1130
# text set: {'when', 'Netflix', 'li', 'with', 'lunch', 'I', 'work', 'of', 'our', 'For', 'us', 'jobs', 'we', 'at', 'many', 'have', 'demand', 'whether', 'people', 'interaction'}
# Identifier: Netflix
# tweet found: True
# Lets begin to record! All the best :)
# latitude: None  logitude: None
# retweet count: 2408
# faviourite count: 0
# hashtags: []
# Insert done!
# Inside tweet function
# Tweet started
# Retweet status: False
# Original tweet: What’s some good shows to watch on Netflix or Hulu
# created at: Sat Nov 30 23:58:07 +0000 2019
# created at: 2019-11-30 18:58:07
# Clean tweet: Whats some good shows to watch on Netflix or Hulu
# Whats some good shows to watch on Netflix or Hulu {'neg': 0.0, 'neu': 0.756, 'pos': 0.244, 'compound': 0.4404}
# polarity: 1
# userId: 2615434187, userName: 👹, userScreenName: Lullsav
# user follower count: 4815, userFollowing: False
# user friends count: 3006
# text set: {'Hulu', 'shows', 'good', 'watch', 'or', 'Whats', 'some', 'to', 'Netflix', 'on'}
# Identifier: Netflix
# tweet found: True
# Lets begin to record! All the best :)
# latitude: None  logitude: None
# retweet count: 0
# faviourite count: 0
# hashtags: []
# Insert done!
# Inside tweet function
# Tweet started
# Retweet status: False
# Original tweet: RT @SwedishLincoln: Hey @netflix quick question, did you forget to include the after credits scene of The Irishman or something?
# created at: Sat Nov 30 23:57:26 +0000 2019
# created at: 2019-11-30 18:57:26
# Clean tweet: Hey quick question did you forget to include the after credits scene of The Irishman or something
# Hey quick question did you forget to include the after credits scene of The Irishman or something {'neg': 0.085, 'neu': 0.804, 'pos': 0.112, 'compound': 0.1531}
# polarity: 1
# userId: 886712771408265216, userName: The Real Omare, userScreenName: laserpants2
# user follower count: 71, userFollowing: False
# user friends count: 88
# text set: {'of', 'the', 'Irishman', 'after', 'you', 'include', 'or', 'something', 'to', 'scene', 'The', 'question', 'forget', 'quick', 'did', 'credits', 'Hey'}
# Identifier: Netflix
# tweet found: False
# Lets begin to record! All the best :)
# latitude: None  logitude: None
# retweet count: 31
# faviourite count: 0
# hashtags: []
# Inside tweet function
# Tweet started
# Retweet status: False
# Original tweet: RT @SarahJKozak: My local newspaper from yesterday💞 we will NOT go unheard or go down WITHOUT a fight !!!! @netflix @Netflixhelps @northwoo…
# created at: Sat Nov 30 23:57:09 +0000 2019
# created at: 2019-11-30 18:57:09
# Clean tweet: My local newspaper from yesterday we will NOT go unheard or go down WITHOUT a fight
# My local newspaper from yesterday we will NOT go unheard or go down WITHOUT a fight {'neg': 0.0, 'neu': 0.856, 'pos': 0.144, 'compound': 0.5191}
# polarity: 1
# userId: 1132089311271239680, userName: ً, userScreenName: booksnhallmark
# user follower count: 2, userFollowing: False
# user friends count: 17
# text set: {'we', 'NOT', 'newspaper', 'My', 'local', 'WITHOUT', 'yesterday', 'or', 'down', 'from', 'go', 'unheard', 'will', 'fight', 'a'}
# Identifier: Netflix
# tweet found: False
# Lets begin to record! All the best :)
# latitude: None  logitude: None
# retweet count: 354
# faviourite count: 0
# hashtags: []
# Inside tweet function
# Tweet started
# Retweet status: False
# Original tweet: I want a dog so it could cuddle with me whenever I’m working on something or watching Netflix 😩💕🐶
# created at: Sat Nov 30 23:56:27 +0000 2019
# created at: 2019-11-30 18:56:27
# Clean tweet: I want a dog so it could cuddle with me whenever Im working on something or watching Netflix
# I want a dog so it could cuddle with me whenever Im working on something or watching Netflix {'neg': 0.0, 'neu': 0.925, 'pos': 0.075, 'compound': 0.0772}
# polarity: 1
# userId: 1176985041114501120, userName: Gigi Q.🥀, userScreenName: chingona25
# user follower count: 28, userFollowing: False
# user friends count: 56
# text set: {'on', 'dog', 'watching', 'working', 'whenever', 'Im', 'want', 'with', 'or', 'could', 'something', 'it', 'Netflix', 'me', 'so', 'I', 'a', 'cuddle'}
# Identifier: Netflix
# tweet found: True
# Lets begin to record! All the best :)
# latitude: None  logitude: None
# retweet count: 0
# faviourite count: 1
# hashtags: []
# Insert done!
# Inside tweet function
# Tweet started
# Retweet status: False
# Original tweet: RT @sun_shine_sonja: If you make #Lucifer #MoreThan5Seasons I am sure Tom Ellis or Lauren German will get an Emmy for it. Don't you wanna k…
# created at: Sat Nov 30 23:56:04 +0000 2019
# created at: 2019-11-30 18:56:04
# Clean tweet: If you make Lucifer MoreThan5Seasons I am sure Tom Ellis or Lauren German will get an Emmy for it Don t you wanna k
# If you make Lucifer MoreThan5Seasons I am sure Tom Ellis or Lauren German will get an Emmy for it Don t you wanna k {'neg': 0.0, 'neu': 0.909, 'pos': 0.091, 'compound': 0.3182}
# polarity: 1
# userId: 1209028327, userName: Marie-Pascale B., userScreenName: Soredamor42
# user follower count: 121, userFollowing: False
# user friends count: 618
# text set: {'Don', 'MoreThan5Seasons', 'Ellis', 'German', 'If', 'you', 'Lucifer', 'will', 'Emmy', 'I', 'Lauren', 'an', 'am', 'or', 'get', 'it', 'for', 't', 'wanna', 'sure', 'make', 'k', 'Tom'}
# Identifier: Netflix
# tweet found: False
# Lets begin to record! All the best :)
# latitude: None  logitude: None
# retweet count: 9
# faviourite count: 0
# hashtags: ['Lucifer', 'MoreThan5Seasons']
# Inside tweet function
# Tweet started
# Retweet status: False
# Original tweet: Pitch perfect 3 is on the uk Netflix now so best believe am watching that instead of packing or sleeping and I have… https://t.co/TiEffi1Td2
# created at: Sat Nov 30 23:55:29 +0000 2019
# created at: 2019-11-30 18:55:29
# Clean tweet: Pitch perfect 3 is on the uk Netflix now so best believe am watching that instead of packing or sleeping and I have
# Pitch perfect 3 is on the uk Netflix now so best believe am watching that instead of packing or sleeping and I have {'neg': 0.0, 'neu': 0.688, 'pos': 0.312, 'compound': 0.8769}
# polarity: 1
# userId: 1148705060089712640, userName: M ɘ l 🏴󠁧󠁢󠁳󠁣󠁴󠁿, userScreenName: kelley_brohara
# user follower count: 105, userFollowing: False
# user friends count: 268
# text set: {'the', 'perfect', 'packing', '3', 'Netflix', 'so', 'is', 'believe', 'uk', 'I', 'now', 'of', 'watching', 'am', 'or', 'instead', 'on', 'Pitch', 'best', 'and', 'that', 'have', 'sleeping'}
# Identifier: Netflix
# tweet found: True
# Lets begin to record! All the best :)
# latitude: None  logitude: None
# retweet count: 0
# faviourite count: 2
# hashtags: []
# Insert done!
# Inside tweet function
# Tweet started
# Retweet status: False
# Original tweet: Is Snapped on Netflix or Hulu or anywhere
# created at: Sat Nov 30 23:55:21 +0000 2019
# created at: 2019-11-30 18:55:21
# Clean tweet: Is Snapped on Netflix or Hulu or anywhere
# Is Snapped on Netflix or Hulu or anywhere {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# polarity: 0
# userId: 702865605, userName: Are You Aware That You Are Ugly?, userScreenName: DuhItzMiaaaa
# user follower count: 1677, userFollowing: False
# user friends count: 577
# text set: {'Hulu', 'Snapped', 'or', 'Is', 'Netflix', 'on', 'anywhere'}
# Identifier: Netflix
# tweet found: True
# Lets begin to record! All the best :)
# latitude: None  logitude: None
# retweet count: 0
# faviourite count: 0
# hashtags: []
# Insert done!
# Inside tweet function
# Tweet started
# Retweet status: False
# Original tweet: RT @TeamRomany: "Holiday Rush" is Trending on Netflix and it's About Time. “I love that we're telling a story about a black, single father…
# created at: Sat Nov 30 23:55:06 +0000 2019
# created at: 2019-11-30 18:55:06
# Clean tweet: Holiday Rush is Trending on Netflix and it s About Time I love that we re telling a story about a black single father
# Holiday Rush is Trending on Netflix and it s About Time I love that we re telling a story about a black single father {'neg': 0.0, 'neu': 0.743, 'pos': 0.257, 'compound': 0.7845}
# polarity: 1
# userId: 2230809143, userName: Jeanette, userScreenName: Jauthor12
# user follower count: 269, userFollowing: False
# user friends count: 291
# text set: {'story', 'Netflix', 'is', 's', 'single', 'Rush', 'Holiday', 'I', 'love', 'telling', 'about', 'father', 'it', 'on', 'About', 'we', 'and', 're', 'that', 'Time', 'Trending', 'black', 'a'}
# Identifier: Netflix
# tweet found: True
# Lets begin to record! All the best :)
# latitude: None  logitude: None
# retweet count: 24
# faviourite count: 0
# hashtags: []
# Insert done!
# Inside tweet function
# Tweet started
# Retweet status: False
# Original tweet: Just me , or us @netflix gotten even more impatient with the “are you still there” pause ........
# created at: Sat Nov 30 23:55:02 +0000 2019
# created at: 2019-11-30 18:55:02
# Clean tweet: Just me or us gotten even more impatient with the are you still there pause
# Just me or us gotten even more impatient with the are you still there pause {'neg': 0.135, 'neu': 0.865, 'pos': 0.0, 'compound': -0.3597}
# polarity: -1
# userId: 173541978, userName: Dan Morse, userScreenName: djmorse126
# user follower count: 176, userFollowing: False
# user friends count: 421
# text set: {'still', 'the', 'gotten', 'you', 'Just', 'pause', 'or', 'with', 'are', 'us', 'there', 'me', 'more', 'impatient', 'even'}
# Identifier: Netflix
# tweet found: False
# Lets begin to record! All the best :)
# latitude: None  logitude: None
# retweet count: 0
# faviourite count: 0
# hashtags: []
# Inside tweet function
# Tweet started
# Retweet status: False
# Original tweet: @thesamwisest Yes, I've had trouble accessing Netflix on my phone sporadically for the last 3 or 4 days now. My lis… https://t.co/RVJSBNHI8C
# created at: Sat Nov 30 23:55:01 +0000 2019
# created at: 2019-11-30 18:55:01
# Clean tweet: Yes I ve had trouble accessing Netflix on my phone sporadically for the last 3 or 4 days now My lis
# Yes I ve had trouble accessing Netflix on my phone sporadically for the last 3 or 4 days now My lis {'neg': 0.115, 'neu': 0.769, 'pos': 0.115, 'compound': 0.0}
# polarity: 0
# userId: 18661594, userName: Tusker2Zero, userScreenName: Tusker2Zero
# user follower count: 13, userFollowing: False
# user friends count: 38
# text set: {'the', 've', '3', 'Netflix', 'accessing', 'last', 'My', 'lis', 'I', '4', 'now', 'my', 'sporadically', 'phone', 'or', 'days', 'on', 'Yes', 'had', 'trouble', 'for'}
# Identifier: Netflix
# tweet found: True
# Lets begin to record! All the best :)
# latitude: None  logitude: None
# retweet count: 0
# faviourite count: 1
# hashtags: []
# Insert done!
# Inside tweet function
# Tweet started
# Retweet status: False
# Original tweet: Anyone have recommendations for good suspense movies or shows on Netflix?
# created at: Sat Nov 30 23:53:42 +0000 2019
# created at: 2019-11-30 18:53:42
# Clean tweet: Anyone have recommendations for good suspense movies or shows on Netflix
# Anyone have recommendations for good suspense movies or shows on Netflix {'neg': 0.0, 'neu': 0.775, 'pos': 0.225, 'compound': 0.4404}
# polarity: 1
# userId: 1148335715131908096, userName: 𝐌𝐲𝐚., userScreenName: indeIIible
# user follower count: 591, userFollowing: False
# user friends count: 323
# text set: {'shows', 'good', 'for', 'Anyone', 'movies', 'or', 'suspense', 'recommendations', 'have', 'Netflix', 'on'}
# Identifier: Netflix
# tweet found: True
# Lets begin to record! All the best :)
# latitude: None  logitude: None
# retweet count: 0
# faviourite count: 1
# hashtags: []
# Insert done!
# Inside tweet function
# Tweet started
# Retweet status: False
# Original tweet: RT @CanoAwae: I really want to wake up one day with news that our show has been renewed. Wheter it's Netflix or any other network really. #…
# created at: Sat Nov 30 23:53:32 +0000 2019
# created at: 2019-11-30 18:53:32
# Clean tweet: I really want to wake up one day with news that our show has been renewed Wheter it s Netflix or any other network really
# I really want to wake up one day with news that our show has been renewed Wheter it s Netflix or any other network really {'neg': 0.0, 'neu': 0.94, 'pos': 0.06, 'compound': 0.1513}
# polarity: 1
# userId: 1132089311271239680, userName: ً, userScreenName: booksnhallmark
# user follower count: 2, userFollowing: False
# user friends count: 17
# text set: {'network', 'Wheter', 'renewed', 'news', 'Netflix', 's', 'has', 'with', 'been', 'wake', 'I', 'one', 'or', 'our', 'to', 'day', 'other', 'it', 'want', 'really', 'that', 'any', 'show', 'up'}
# Identifier: Netflix
# tweet found: True
# Lets begin to record! All the best :)
# latitude: None  logitude: None
# retweet count: 61
# faviourite count: 0
# hashtags: []
# Insert done!
# Inside tweet function
# Tweet started
# Retweet status: False
# Original tweet: A.) Chose the wrong time for a movie like someone with ADD
# 2.) NOT a Scorsese fan and watched for trending purpose… https://t.co/Ce4xIZeFwl
# created at: Sat Nov 30 23:53:32 +0000 2019
# created at: 2019-11-30 18:53:32
# Clean tweet: A Chose the wrong time for a movie like someone with ADD 2 NOT a Scorsese fan and watched for trending purpose
# A Chose the wrong time for a movie like someone with ADD 2 NOT a Scorsese fan and watched for trending purpose {'neg': 0.198, 'neu': 0.704, 'pos': 0.098, 'compound': -0.374}
# polarity: -1
# userId: 74082044, userName: ROMEO, userScreenName: YomamaluvnRomeo
# user follower count: 708, userFollowing: False
# user friends count: 1716
# text set: {'ADD', 'the', 'NOT', 'purpose', 'trending', 'time', 'fan', 'Chose', 'with', 'Scorsese', 'like', 'watched', '2', 'movie', 'someone', 'and', 'A', 'for', 'wrong', 'a'}
# Identifier: Netflix
# tweet found: False
# Lets begin to record! All the best :)
# latitude: None  logitude: None
# retweet count: 0
# faviourite count: 0
# hashtags: []
# Inside tweet function
# Tweet started
# Retweet status: False
# Original tweet: RT @patriotgirl5: 666 is the MAGIC number. If every Lucifriend tweets or RTs 666 times to save LUCIFER today – we will trend on Twitter! We…
# created at: Sat Nov 30 23:53:26 +0000 2019
# created at: 2019-11-30 18:53:26
# Clean tweet: 66 is the MAGIC number If every Lucifriend tweets or RTs 66 times to save LUCIFER today we will trend on Twitter We
# 66 is the MAGIC number If every Lucifriend tweets or RTs 66 times to save LUCIFER today we will trend on Twitter We {'neg': 0.0, 'neu': 0.828, 'pos': 0.172, 'compound': 0.5848}
# polarity: 1
# userId: 245942815, userName: Mick San, userScreenName: Siwckc
# user follower count: 421, userFollowing: False
# user friends count: 1103
# text set: {'tweets', 'the', 'RTs', 'Lucifriend', 'Twitter', 'every', 'is', '66', 'If', 'trend', 'today', 'We', 'will', 'LUCIFER', 'or', 'times', 'to', 'on', 'we', 'MAGIC', 'number', 'save'}
# Identifier: Netflix
# tweet found: False
# Lets begin to record! All the best :)
# latitude: None  logitude: None
# retweet count: 11
# faviourite count: 0
# hashtags: []
# Inside tweet function
# Tweet started
# Retweet status: False
# Original tweet: RT @TeamRomany: "Holiday Rush" is Trending on Netflix and it's About Time. “I love that we're telling a story about a black, single father…
# created at: Sat Nov 30 23:53:23 +0000 2019
# created at: 2019-11-30 18:53:23
# Clean tweet: Holiday Rush is Trending on Netflix and it s About Time I love that we re telling a story about a black single father
# Holiday Rush is Trending on Netflix and it s About Time I love that we re telling a story about a black single father {'neg': 0.0, 'neu': 0.743, 'pos': 0.257, 'compound': 0.7845}
# polarity: 1
# userId: 35967562, userName: julia mercer, userScreenName: FTL18Julia
# user follower count: 3144, userFollowing: False
# user friends count: 4959
# text set: {'story', 'Netflix', 'is', 's', 'single', 'Rush', 'Holiday', 'I', 'love', 'telling', 'about', 'father', 'it', 'on', 'About', 'we', 'and', 're', 'that', 'Time', 'Trending', 'black', 'a'}
# Identifier: Netflix
# tweet found: True
# Lets begin to record! All the best :)
# latitude: None  logitude: None
# retweet count: 24
# faviourite count: 0
# hashtags: []
# Insert done!
# Inside tweet function
# Tweet started
# Retweet status: False
# Original tweet: This #bikram #yoga documentary on @netflix is insane. If you’ve ever done bikram yoga or were hoping to attend a te… https://t.co/quKIg14JYi
# created at: Sat Nov 30 23:52:17 +0000 2019
# created at: 2019-11-30 18:52:17
# Clean tweet: This bikram yoga documentary on is insane If youve ever done bikram yoga or were hoping to attend a te
# This bikram yoga documentary on is insane If youve ever done bikram yoga or were hoping to attend a te {'neg': 0.11, 'neu': 0.776, 'pos': 0.114, 'compound': 0.0258}
# polarity: 0
# userId: 7221022, userName: Afonso Salcedo, userScreenName: fonziewonzie
# user follower count: 1292, userFollowing: False
# user friends count: 1407
# text set: {'documentary', 'on', 'If', 'insane', 'hoping', 'is', 'or', 'done', 'to', 'were', 'bikram', 'yoga', 'te', 'youve', 'This', 'ever', 'a', 'attend'}
# Identifier: Netflix
# tweet found: False
# Lets begin to record! All the best :)
# latitude: None  logitude: None
# retweet count: 0
# faviourite count: 0
# hashtags: ['bikram', 'yoga']
# Inside tweet function
# Tweet started
# Retweet status: False
# Original tweet: RT @Macys: Sam and Guy’s hammobile on @netflix’s Green Eggs and Ham balloon is big enough to fit 4 million eggs or 14,000 hams. #macysparad…
# created at: Sat Nov 30 23:51:56 +0000 2019
# created at: 2019-11-30 18:51:56
# Clean tweet: Sam and Guys hammobile on Green Eggs and Ham balloon is big enough to fit 4 million eggs or 14 00 hams macysparad
# Sam and Guys hammobile on Green Eggs and Ham balloon is big enough to fit 4 million eggs or 14 00 hams macysparad {'neg': 0.0, 'neu': 0.902, 'pos': 0.098, 'compound': 0.3612}
# polarity: 1
# userId: 975511521643122690, userName: Lecus, userScreenName: Lecus5
# user follower count: 1, userFollowing: False
# user friends count: 12
# text set: {'Sam', 'million', 'is', 'eggs', 'fit', 'Ham', 'Guys', '4', 'macysparad', 'Green', 'Eggs', 'or', 'to', 'on', 'big', '00', 'and', 'balloon', 'hammobile', 'hams', 'enough', '14'}
# Identifier: Netflix
# tweet found: False
# Lets begin to record! All the best :)
# latitude: None  logitude: None
# retweet count: 109
# faviourite count: 0
# hashtags: []
# Inside tweet function
# Tweet started
# Retweet status: False
# Original tweet: Netflix suggestions? ... or should I say fuck it and cop the Disney+ ?.. decisions ⛪️ .
# created at: Sat Nov 30 23:51:51 +0000 2019
# created at: 2019-11-30 18:51:51
# Clean tweet: Netflix suggestions or should I say fuck it and cop the Disney decisions
# Netflix suggestions or should I say fuck it and cop the Disney decisions {'neg': 0.216, 'neu': 0.784, 'pos': 0.0, 'compound': -0.594}
# polarity: -1
# userId: 16481985, userName: Kilo Santana ⛪️, userScreenName: OhMyGodGRAM
# user follower count: 1797, userFollowing: False
# user friends count: 416
# text set: {'suggestions', 'and', 'fuck', 'the', 'say', 'decisions', 'should', 'or', 'Netflix', 'cop', 'Disney', 'it', 'I'}
# Identifier: Netflix
# tweet found: True
# Lets begin to record! All the best :)
# latitude: None  logitude: None
# retweet count: 0
# faviourite count: 3
# hashtags: []
# Insert done!
# Inside tweet function
# Tweet started
# Retweet status: False
# Original tweet: @ShadowBriton @CMCoys Sky or streams they took it off Netflix😭😭😭
# created at: Sat Nov 30 23:51:51 +0000 2019
# created at: 2019-11-30 18:51:51
# Clean tweet: Sky or streams they took it off Netflix
# Sky or streams they took it off Netflix- {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# polarity: 0
# userId: 1131334213410656257, userName: Scarlett, userScreenName: bxnnydavies
# user follower count: 1579, userFollowing: False
# user friends count: 1110
# text set: {'off', 'took', 'Sky', 'or', 'it', 'Netflix', 'streams', 'they'}
# Identifier: Netflix
# tweet found: True
# Lets begin to record! All the best :)
# latitude: None  logitude: None
# retweet count: 0
# faviourite count: 1
# hashtags: []
# Insert done!
# Inside tweet function
# Tweet started
# Retweet status: False
# Original tweet: I know it’s the holiday season &amp; all but wtf @STAR can’t y’all go to @netflix or @hulu 😩😩😩
# created at: Sat Nov 30 23:51:51 +0000 2019
# created at: 2019-11-30 18:51:51
# Clean tweet: I know its the holiday season amp all but wtf cant yall go to or
# I know its the holiday season amp all but wtf cant yall go to or {'neg': 0.226, 'neu': 0.694, 'pos': 0.08, 'compound': -0.6542}
# polarity: -1
# userId: 26249535, userName: The Lord 💀, userScreenName: MagnificentVee
# user follower count: 1271, userFollowing: False
# user friends count: 909
# text set: {'its', 'the', 'wtf', 'yall', 'or', 'but', 'cant', 'to', 'go', 'all', 'know', 'season', 'holiday', 'I', 'amp'}
# Identifier: Netflix
# tweet found: False
# Lets begin to record! All the best :)
# latitude: None  logitude: None
# retweet count: 0
# faviourite count: 0
# hashtags: []
# Inside tweet function
# Tweet started
# Retweet status: False
# Original tweet: I'm not big on crime or mafia movies, but @TheIrishmanFilm was... perfect. loved it from the very beginning until t… https://t.co/6qr5WKmLWi
# created at: Sat Nov 30 23:51:25 +0000 2019
# created at: 2019-11-30 18:51:25
# Clean tweet: I m not big on crime or mafia movies but was perfect loved it from the very beginning until t
# I m not big on crime or mafia movies but was perfect loved it from the very beginning until t {'neg': 0.0, 'neu': 0.594, 'pos': 0.406, 'compound': 0.9235}
# polarity: 1
# userId: 2425334731, userName: Mirosław Sebastian, userScreenName: M_Kolodziej
# user follower count: 33, userFollowing: False
# user friends count: 185
# text set: {'the', 'perfect', 'until', 'beginning', 'but', 'I', 'm', 'crime', 'movies', 'or', 'was', 'very', 'not', 'it', 'on', 'big', 'loved', 'mafia', 't', 'from'}
# Identifier: Netflix
# tweet found: False
# Lets begin to record! All the best :)
# latitude: None  logitude: None
# retweet count: 0
# faviourite count: 1
# hashtags: []
# Inside tweet function
# Tweet started
# Retweet status: False
# Original tweet: Hmmm 🤔 should i go to sleep or watch Netflix?! https://t.co/2V6sb4DDco
# created at: Sat Nov 30 23:50:46 +0000 2019
# created at: 2019-11-30 18:50:46
# Clean tweet: Hmm should i go to sleep or watch Netflix
# Hmm should i go to sleep or watch Netflix {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# polarity: 0
# userId: 880062560753635328, userName: シ, userScreenName: Oktameee
# user follower count: 106, userFollowing: False
# user friends count: 92
# text set: {'Hmm', 'watch', 'should', 'or', 'to', 'Netflix', 'go', 'i', 'sleep'}
# Identifier: Netflix
# tweet found: True
# Lets begin to record! All the best :)
# latitude: None  logitude: None
# retweet count: 0
# faviourite count: 2
# hashtags: []
# Insert done!
# Inside tweet function
# Tweet started
# Retweet status: False
# Original tweet: @dragonfire20 Oh wow I didn't know that. You don't have Netflix right?? Well, they're available on Hulu and Netflix… https://t.co/rz4zGuxigd
# created at: Sat Nov 30 23:50:41 +0000 2019
# created at: 2019-11-30 18:50:41
# Clean tweet: Oh wow I didn t know that You don t have Netflix right Well they re available on Hulu and Netflix
# Oh wow I didn t know that You don t have Netflix right Well they re available on Hulu and Netflix {'neg': 0.0, 'neu': 0.731, 'pos': 0.269, 'compound': 0.7399}
# polarity: 1
# userId: 296285008, userName: 𝔇𝔞𝔯𝔠𝔶 𝔉𝔞𝔯𝔯𝔬𝔴 🎅🏼🌈🍭❄️⛄️, userScreenName: MsDarcyFarrow
# user follower count: 4461, userFollowing: False
# user friends count: 3736
# text set: {'don', 'Netflix', 'Hulu', 'I', 'available', 'Oh', 'You', 'wow', 'on', 'they', 'Well', 'and', 't', 're', 'that', 'didn', 'right', 'have', 'know'}
# Identifier: Netflix
# tweet found: True
# Lets begin to record! All the best :)
# latitude: None  logitude: None
# retweet count: 0
# faviourite count: 1
# hashtags: []
# Insert done!
# Inside tweet function
# Tweet started
# Retweet status: False
# Original tweet: @KnaIsAFlop it’s the untamed!! also they are canon, though due to China’s censorship and such the show doesn’t expl… https://t.co/5QO2b27RGo
# created at: Sat Nov 30 23:50:21 +0000 2019
# created at: 2019-11-30 18:50:21
# Clean tweet: its the untamed also they are canon though due to Chinas censorship and such the show doesnt expl
# its the untamed also they are canon though due to Chinas censorship and such the show doesnt expl {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# polarity: 0
# userId: 867591446412623880, userName: jinnie baby day 🐹💘, userScreenName: polyrapIine
# user follower count: 528, userFollowing: False
# user friends count: 254
# text set: {'canon', 'also', 'censorship', 'its', 'and', 'the', 'doesnt', 'Chinas', 'though', 'untamed', 'are', 'to', 'show', 'such', 'due', 'they', 'expl'}
# Identifier: Netflix
# tweet found: False
# Lets begin to record! All the best :)
# latitude: None  logitude: None
# retweet count: 0
# faviourite count: 0
# hashtags: []
# Inside tweet function
# Tweet started
# Retweet status: False
# Original tweet: RT @xxxInDeRxxx1: At least someone keeps their mind not like other...@netflix or @CBC .... #renewannewithane #SaveAnneWithAnnE #WE_WANT_AWA…
# created at: Sat Nov 30 23:50:06 +0000 2019
# created at: 2019-11-30 18:50:06
# Clean tweet: At least someone keeps their mind not like other or renewannewithane SaveAnneWithAnnE WE WANT AWA
# At least someone keeps their mind not like other or renewannewithane SaveAnneWithAnnE WE WANT AWA {'neg': 0.117, 'neu': 0.883, 'pos': 0.0, 'compound': -0.2755}
# polarity: -1
# userId: 1199148363217866752, userName: Itzel Ortiz, userScreenName: ItzelOr34481144
# user follower count: 128, userFollowing: False
# user friends count: 195
# text set: {'someone', 'least', 'At', 'mind', 'SaveAnneWithAnnE', 'renewannewithane', 'WE', 'or', 'AWA', 'their', 'keeps', 'WANT', 'not', 'other', 'like'}
# Identifier: Netflix
# tweet found: False
# Lets begin to record! All the best :)
# latitude: None  logitude: None
# retweet count: 1
# faviourite count: 0
# hashtags: ['renewannewithane', 'SaveAnneWithAnnE']
# Inside tweet function
# Tweet started
# Retweet status: False
# Original tweet: @bxnnydavies @CMCoys I'll give it a watch. Is it on Netflix or somewhere?
# created at: Sat Nov 30 23:49:47 +0000 2019
# created at: 2019-11-30 18:49:47
# Clean tweet: I ll give it a watch Is it on Netflix or somewhere
# I ll give it a watch Is it on Netflix or somewhere {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# polarity: 0
# userId: 852262270348517377, userName: Tom ⚫⚪, userScreenName: ShadowBriton
# user follower count: 2445, userFollowing: False
# user friends count: 4074
# text set: {'on', 'll', 'watch', 'or', 'Is', 'Netflix', 'somewhere', 'give', 'it', 'I', 'a'}
# Identifier: Netflix
# tweet found: True
# Lets begin to record! All the best :)
# latitude: None  logitude: None
# retweet count: 0
# faviourite count: 0
# hashtags: []
# Insert done!
# Inside tweet function
# Tweet started
# Retweet status: False
# Original tweet: RT @thehorsegirl15: Amenadiel: You are a mockery of everything divine.
# Lucifer: Thank you. Thank you, but lately I've been thinking. Do yo…
# created at: Sat Nov 30 23:49:08 +0000 2019
# created at: 2019-11-30 18:49:08
# Clean tweet: Amenadiel You are a mockery of everything divine Lucifer Thank you Thank you but lately I ve been thinking Do yo
# Amenadiel You are a mockery of everything divine Lucifer Thank you Thank you but lately I ve been thinking Do yo {'neg': 0.067, 'neu': 0.695, 'pos': 0.237, 'compound': 0.4854}
# polarity: 1
# userId: 322022153, userName: patriotgirl5, userScreenName: patriotgirl5
# user follower count: 618, userFollowing: False
# user friends count: 2370
# text set: {'yo', 'lately', 'Do', 've', 'divine', 'mockery', 'you', 'Thank', 'but', 'been', 'Lucifer', 'I', 'of', 'You', 'everything', 'are', 'Amenadiel', 'thinking', 'a'}
# Identifier: Netflix
# tweet found: False
# Lets begin to record! All the best :)
# latitude: None  logitude: None
# retweet count: 2
# faviourite count: 0
# hashtags: []
# Inside tweet function
# Tweet started
# Retweet status: False
# Original tweet: Why Sharing Your Disney+ or Netflix Password Is a Bad Idea https://t.co/rNixM4DgPh via @gizmodo
# created at: Sat Nov 30 23:48:57 +0000 2019
# created at: 2019-11-30 18:48:57
# Clean tweet: Why Sharing Your Disney or Netflix Password Is a Bad Idea via
# Why Sharing Your Disney or Netflix Password Is a Bad Idea via {'neg': 0.202, 'neu': 0.636, 'pos': 0.162, 'compound': -0.1779}
# polarity: -1
# userId: 3933205948, userName: tara harris~..., userScreenName: tarataracl0ud
# user follower count: 155, userFollowing: False
# user friends count: 711
# text set: {'Password', 'via', 'Idea', 'or', 'Your', 'Sharing', 'Is', 'Netflix', 'Disney', 'Why', 'a', 'Bad'}
# Identifier: Netflix
# tweet found: True
# Lets begin to record! All the best :)
# latitude: None  logitude: None
# retweet count: 0
# faviourite count: 0
# hashtags: []
# Insert done!
# Inside tweet function
# Tweet started
# Retweet status: False
# Original tweet: RT @SarahJKozak: My local newspaper from yesterday💞 we will NOT go unheard or go down WITHOUT a fight !!!! @netflix @Netflixhelps @northwoo…
# created at: Sat Nov 30 23:48:45 +0000 2019
# created at: 2019-11-30 18:48:45
# Clean tweet: My local newspaper from yesterday we will NOT go unheard or go down WITHOUT a fight
# My local newspaper from yesterday we will NOT go unheard or go down WITHOUT a fight {'neg': 0.0, 'neu': 0.856, 'pos': 0.144, 'compound': 0.5191}
# polarity: 1
# userId: 1146422223290413056, userName: Anil zineb, userScreenName: AnilZineb
# user follower count: 20, userFollowing: False
# user friends count: 30
# text set: {'we', 'NOT', 'newspaper', 'My', 'local', 'WITHOUT', 'yesterday', 'or', 'down', 'from', 'go', 'unheard', 'will', 'fight', 'a'}
# Identifier: Netflix
# tweet found: False
# Lets begin to record! All the best :)
# latitude: None  logitude: None
# retweet count: 354
# faviourite count: 0
# hashtags: []
# Inside tweet function
# Tweet started
# Retweet status: False
# Original tweet: At least someone keeps their mind not like other...@netflix or @CBC .... #renewannewithane #SaveAnneWithAnnE… https://t.co/xsB5IZbj7I
# created at: Sat Nov 30 23:48:38 +0000 2019
# created at: 2019-11-30 18:48:38
# Clean tweet: At least someone keeps their mind not like other or renewannewithane SaveAnneWithAnnE
# At least someone keeps their mind not like other or renewannewithane SaveAnneWithAnnE {'neg': 0.131, 'neu': 0.869, 'pos': 0.0, 'compound': -0.2755}
# polarity: -1
# userId: 1199362555514413056, userName: xxxInDeRxxx, userScreenName: xxxInDeRxxx1
# user follower count: 8, userFollowing: False
# user friends count: 40
# text set: {'someone', 'least', 'At', 'mind', 'SaveAnneWithAnnE', 'renewannewithane', 'or', 'their', 'keeps', 'not', 'other', 'like'}
# Identifier: Netflix
# tweet found: False
# Lets begin to record! All the best :)
# latitude: None  logitude: None
# retweet count: 1
# faviourite count: 1
# hashtags: ['renewannewithane', 'SaveAnneWithAnnE']
# Inside tweet function
# Tweet started
# Retweet status: False
# Original tweet: RT @vegannutrition1: Have you seen the #GameChangersMovie and want to learn more about a #plantbased diet?
#
# These films have had a life cha…
# created at: Sat Nov 30 23:48:05 +0000 2019
# created at: 2019-11-30 18:48:05
# Clean tweet: Have you seen the GameChangersMovie and want to learn more about a plantbased diet These films have had a life cha
# Have you seen the GameChangersMovie and want to learn more about a plantbased diet These films have had a life cha {'neg': 0.0, 'neu': 0.939, 'pos': 0.061, 'compound': 0.0772}
# polarity: 1
# userId: 457368086, userName: Amy Baker, userScreenName: aabaker_amy
# user follower count: 674, userFollowing: False
# user friends count: 4614
# text set: {'the', 'These', 'cha', 'plantbased', 'you', 'diet', 'Have', 'GameChangersMovie', 'more', 'about', 'films', 'to', 'life', 'and', 'seen', 'had', 'want', 'learn', 'have', 'a'}
# Identifier: Netflix
# tweet found: False
# Lets begin to record! All the best :)
# latitude: None  logitude: None
# retweet count: 94
# faviourite count: 0
# hashtags: ['GameChangersMovie', 'plantbased']
# Inside tweet function
# Tweet started
# Retweet status: False
# Original tweet: @DawnTheSoapGurl U can get Netflix on the wii / wii u but a switch or ds ffs
# created at: Sat Nov 30 23:47:59 +0000 2019
# created at: 2019-11-30 18:47:59
# Clean tweet: U can get Netflix on the wii wii u but a switch or ds ffs
# U can get Netflix on the wii wii u but a switch or ds ffs {'neg': 0.302, 'neu': 0.698, 'pos': 0.0, 'compound': -0.7351}
# polarity: -1
# userId: 1010202624250056704, userName: Ryan is a bi communist ☭, userScreenName: spide2015
# user follower count: 61, userFollowing: False
# user friends count: 292
# text set: {'can', 'switch', 'the', 'u', 'ffs', 'or', 'wii', 'U', 'but', 'Netflix', 'get', 'ds', 'on', 'a'}
# Identifier: Netflix
# tweet found: True
# Lets begin to record! All the best :)
# latitude: None  logitude: None
# retweet count: 0
# faviourite count: 0
# hashtags: []
# Insert done!
# Inside tweet function
# Tweet started
# Retweet status: False
# Original tweet: Amenadiel: You are a mockery of everything divine.
# Lucifer: Thank you. Thank you, but lately I've been thinking. D… https://t.co/16ckq4osy8
# created at: Sat Nov 30 23:47:56 +0000 2019
# created at: 2019-11-30 18:47:56
# Clean tweet: Amenadiel You are a mockery of everything divine Lucifer Thank you Thank you but lately I ve been thinking D
# Amenadiel You are a mockery of everything divine Lucifer Thank you Thank you but lately I ve been thinking D {'neg': 0.073, 'neu': 0.668, 'pos': 0.258, 'compound': 0.4854}
# polarity: 1
# userId: 995052921359294464, userName: Gerri Petersen:You don't scare me. I ride a mare., userScreenName: thehorsegirl15
# user follower count: 363, userFollowing: False
# user friends count: 823
# text set: {'of', 'D', 'thinking', 'you', 'You', 'lately', 'everything', 'are', 'Thank', 'but', 'Lucifer', 've', 'been', 'divine', 'Amenadiel', 'I', 'a', 'mockery'}
# Identifier: Netflix
# tweet found: False
# Lets begin to record! All the best :)
# latitude: None  logitude: None
# retweet count: 2
# faviourite count: 6
# hashtags: []
# Inside tweet function
# Tweet started
# Retweet status: False
# Original tweet: Hey @netflix add an option in settings to disable the auto-preview """""feature""""" before the end of the year or… https://t.co/Jded67v53o
# created at: Sat Nov 30 23:47:36 +0000 2019
# created at: 2019-11-30 18:47:36
# Clean tweet: Hey add an option in settings to disable the auto preview feature before the end of the year or
# Hey add an option in settings to disable the auto preview feature before the end of the year or {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# polarity: 0
# userId: 1189621777036644352, userName: Bankrupt, morally AND creatively, userScreenName: drop_off_artist
# user follower count: 9, userFollowing: False
# user friends count: 15
# text set: {'preview', 'year', 'an', 'of', 'the', 'settings', 'feature', 'in', 'disable', 'auto', 'or', 'before', 'to', 'add', 'option', 'Hey', 'end'}
# Identifier: Netflix
# tweet found: False
# Lets begin to record! All the best :)
# latitude: None  logitude: None
# retweet count: 1
# faviourite count: 2
# hashtags: []
# Inside tweet function
# Tweet started
# Retweet status: False
# Original tweet: @netflix Where is the HD or 4k support for my Pixel Slate? Brand new device. I'm paying you a premium, and you can'… https://t.co/4if8GmZPO5
# created at: Sat Nov 30 23:47:24 +0000 2019
# created at: 2019-11-30 18:47:24
# Clean tweet: Where is the HD or 4k support for my Pixel Slate Brand new device I m paying you a premium and you can
# Where is the HD or 4k support for my Pixel Slate Brand new device I m paying you a premium and you can {'neg': 0.0, 'neu': 0.891, 'pos': 0.109, 'compound': 0.4019}
# polarity: 1
# userId: 18759137, userName: crogs, userScreenName: crogs
# user follower count: 12, userFollowing: False
# user friends count: 22
# text set: {'the', 'Where', '4k', 'is', 'Pixel', 'you', 'I', 'm', 'can', 'premium', 'my', 'device', 'or', 'support', 'and', 'Brand', 'for', 'Slate', 'HD', 'new', 'a', 'paying'}
# Identifier: Netflix
# tweet found: False
# Lets begin to record! All the best :)
# latitude: None  logitude: None
# retweet count: 0
# faviourite count: 0
# hashtags: []
# Inside tweet function
# Tweet started
# Retweet status: False
# Original tweet: RT @thehorsegirl15: The name, "Mazikeen," comes from the name of a kind of demon from Jewish mythology; which are invisible demons which ca…
# created at: Sat Nov 30 23:46:57 +0000 2019
# created at: 2019-11-30 18:46:57
# Clean tweet: The name Mazikeen comes from the name of a kind of demon from Jewish mythology which are invisible demons which ca
# The name Mazikeen comes from the name of a kind of demon from Jewish mythology which are invisible demons which ca {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# polarity: 0
# userId: 322022153, userName: patriotgirl5, userScreenName: patriotgirl5
# user follower count: 618, userFollowing: False
# user friends count: 2370
# text set: {'which', 'kind', 'of', 'the', 'Mazikeen', 'demons', 'Jewish', 'invisible', 'comes', 'ca', 'are', 'mythology', 'from', 'The', 'demon', 'a', 'name'}
# Identifier: Netflix
# tweet found: False
# Lets begin to record! All the best :)
# latitude: None  logitude: None
# retweet count: 3
# faviourite count: 0
# hashtags: []
# Inside tweet function
# Tweet started
# Retweet status: False
# Original tweet: idk if y’all know this or not make sure you’re really careful when you’re watching netflix in the tub and ESPECIALL… https://t.co/s4k9FtVXzw
# created at: Sat Nov 30 23:46:49 +0000 2019
# created at: 2019-11-30 18:46:49
# Clean tweet: idk if yall know this or not make sure youre really careful when youre watching netflix in the tub and ESPECIALL
# idk if yall know this or not make sure youre really careful when youre watching netflix in the tub and ESPECIALL {'neg': 0.139, 'neu': 0.783, 'pos': 0.078, 'compound': -0.1202}
# polarity: -1
# userId: 1733438557, userName: Turkey Con, userScreenName: ConnieSircar
# user follower count: 371, userFollowing: False
# user friends count: 425
# text set: {'when', 'the', 'in', 'idk', 'ESPECIALL', 'netflix', 'tub', 'if', 'this', 'youre', 'yall', 'watching', 'or', 'not', 'and', 'really', 'sure', 'careful', 'know', 'make'}
# Identifier: Netflix
# tweet found: True
# Lets begin to record! All the best :)
# latitude: None  logitude: None
# retweet count: 0
# faviourite count: 0
# hashtags: []
# Insert done!
# Inside tweet function
# Tweet started
# Retweet status: False
# Original tweet: @LilyCrue @doctormromeo @aalkermd @EMinMiami @miguel_reyesMD @colleenmfarrell @DaveLewMD @joannhsuuu @JayLin3455… https://t.co/gJL9BHyfhl
# created at: Sat Nov 30 23:45:57 +0000 2019
# created at: 2019-11-30 18:45:57
# Clean tweet: reyesMD
# reyesMD--------------------------------- {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# polarity: 0
# userId: 785968989092446209, userName: Jessi Gold, userScreenName: drjessigold
# user follower count: 8626, userFollowing: False
# user friends count: 2403
# text set: {'reyesMD'}
# Identifier: Netflix
# tweet found: False
# Lets begin to record! All the best :)
# latitude: None  logitude: None
# retweet count: 0
# faviourite count: 1
# hashtags: []
# Inside tweet function
# Tweet started
# Retweet status: False
# Original tweet: I need a movie that’s going to make me cry that’s on Disney+ or Netflix... suggestions?
# created at: Sat Nov 30 23:45:56 +0000 2019
# created at: 2019-11-30 18:45:56
# Clean tweet: I need a movie thats going to make me cry thats on Disney or Netflix suggestions
# I need a movie thats going to make me cry thats on Disney or Netflix suggestions {'neg': 0.193, 'neu': 0.807, 'pos': 0.0, 'compound': -0.4767}
# polarity: -1
# userId: 433053734, userName: chloxo, userScreenName: chloee_annette
# user follower count: 258, userFollowing: False
# user friends count: 449
# text set: {'need', 'suggestions', 'cry', 'a', 'going', 'Disney', 'or', 'thats', 'to', 'Netflix', 'me', 'make', 'on', 'I', 'movie'}
# Identifier: Netflix
# tweet found: True
# Lets begin to record! All the best :)
# latitude: None  logitude: None
# retweet count: 0
# faviourite count: 0
# hashtags: []
# Insert done!
# Inside tweet function
# Tweet started
# Retweet status: False
# Original tweet: RT @jakeholla: look i love Disney, but this is the 2nd year in a row that the best animated film wasn’t Disney or Disney/Pixar. 2018 gave u…
# created at: Sat Nov 30 23:45:41 +0000 2019
# created at: 2019-11-30 18:45:41
# Clean tweet: look i love Disney but this is the 2nd year in a row that the best animated film wasnt Disney or Disney Pixar 2018 gave u
# look i love Disney but this is the 2nd year in a row that the best animated film wasnt Disney or Disney Pixar 2018 gave u {'neg': 0.0, 'neu': 0.732, 'pos': 0.268, 'compound': 0.8555}
# polarity: 1
# userId: 3070906978, userName: Samchan ❄️❄️, userScreenName: sammystroodle
# user follower count: 568, userFollowing: False
# user friends count: 634
# text set: {'the', 'in', 'is', 'film', 'look', 'u', 'but', 'i', '2018', 'this', 'Disney', 'Pixar', 'love', 'year', 'gave', 'or', 'animated', 'row', '2nd', 'best', 'that', 'wasnt', 'a'}
# Identifier: Netflix
# tweet found: False
# Lets begin to record! All the best :)
# latitude: None  logitude: None
# retweet count: 190
# faviourite count: 0
# hashtags: []
# Inside tweet function
# Tweet started
# Retweet status: False
# Original tweet: @jackietrevino21 Always be my maybe or undercover brother 2 are pretty good movies on Netflix in my opinion
# created at: Sat Nov 30 23:44:53 +0000 2019
# created at: 2019-11-30 18:44:53
# Clean tweet: Always be my maybe or undercover brother 2 are pretty good movies on Netflix in my opinion
# Always be my maybe or undercover brother 2 are pretty good movies on Netflix in my opinion {'neg': 0.0, 'neu': 0.711, 'pos': 0.289, 'compound': 0.7269}
# polarity: 1
# userId: 1105597062005972999, userName: Sancho Clause 🎅🏽, userScreenName: bambino_marito
# user follower count: 171, userFollowing: False
# user friends count: 223
# text set: {'maybe', 'be', 'on', 'opinion', 'my', 'Always', 'good', 'movies', 'in', 'or', 'brother', 'are', 'Netflix', 'undercover', 'pretty', '2'}
# Identifier: Netflix
# tweet found: True
# Lets begin to record! All the best :)
# latitude: None  logitude: None
# retweet count: 0
# faviourite count: 0
# hashtags: []
# Insert done!
# Inside tweet function
# Tweet started
# Retweet status: False
# Original tweet: RT @MatthewEspinosa: hey @netflix I noticed you put @BeSomebodyMovie back! (ily) Can I take y’all out to dinner or something? I got a coupl…
# created at: Sat Nov 30 23:44:36 +0000 2019
# created at: 2019-11-30 18:44:36
# Clean tweet: hey I noticed you put back ily Can I take yall out to dinner or something I got a coupl
# hey I noticed you put back ily Can I take yall out to dinner or something I got a coupl {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# polarity: 0
# userId: 882782421447561218, userName: Trenary | turns 16 in 4 days | GIVEAWAY PINNED, userScreenName: brionsbloodline
# user follower count: 6685, userFollowing: False
# user friends count: 7088
# text set: {'noticed', 'back', 'put', 'got', 'coupl', 'Can', 'take', 'you', 'yall', 'hey', 'or', 'something', 'to', 'out', 'ily', 'dinner', 'I', 'a'}
# Identifier: Netflix
# tweet found: False
# Lets begin to record! All the best :)
# latitude: None  logitude: None
# retweet count: 125
# faviourite count: 0
# hashtags: []
# Inside tweet function
# Tweet started
# Retweet status: False
# Original tweet: @Lifeis_SoWeird @disneyplus Dang, dude, that sucks! I’ve been waiting till my favorite shows go on to even think ab… https://t.co/56gmKOOnvc
# created at: Sat Nov 30 23:44:22 +0000 2019
# created at: 2019-11-30 18:44:22
# Clean tweet: SoWeird Dang dude that sucks Ive been waiting till my favorite shows go on to even think ab
# SoWeird Dang dude that sucks Ive been waiting till my favorite shows go on to even think ab {'neg': 0.105, 'neu': 0.757, 'pos': 0.138, 'compound': 0.2003}
# polarity: 1
# userId: 512761346, userName: Keith Stuart, userScreenName: Keither37
# user follower count: 293, userFollowing: False
# user friends count: 509
# text set: {'shows', 'think', 'on', 'my', 'ab', 'favorite', 'Dang', 'sucks', 'that', 'SoWeird', 'Ive', 'been', 'till', 'go', 'to', 'dude', 'waiting', 'even'}
# Identifier: Netflix
# tweet found: False
# Lets begin to record! All the best :)
# latitude: None  logitude: None
# retweet count: 0
# faviourite count: 1
# hashtags: []
# Inside tweet function
# Tweet started
# Retweet status: False
# Original tweet: @nellietellie @radiolemans @SkySportsF1 @BlackpoolJonny Awesome here I was expecting to find it on Netflix or somet… https://t.co/1dEMgDgFhC
# created at: Sat Nov 30 23:44:11 +0000 2019
# created at: 2019-11-30 18:44:11
# Clean tweet: Awesome here I was expecting to find it on Netflix or somet
# Awesome here I was expecting to find it on Netflix or somet {'neg': 0.0, 'neu': 0.785, 'pos': 0.215, 'compound': 0.6249}
# polarity: 1
# userId: 154464924, userName: Joost, userScreenName: _Joostk_
# user follower count: 212, userFollowing: False
# user friends count: 227
# text set: {'here', 'on', 'somet', 'expecting', 'find', 'or', 'to', 'Netflix', 'was', 'Awesome', 'it', 'I'}
# Identifier: Netflix
# tweet found: True
# Lets begin to record! All the best :)
# latitude: None  logitude: None
# retweet count: 0
# faviourite count: 0
# hashtags: []
# Insert done!
# Inside tweet function
# Tweet started
# Retweet status: False
# Original tweet: RT @waywardbaz: i dont know how to reiterate this anymore - do not watch tdp on netflix &amp; do not hype it up, not only because aaron doesn't…
# created at: Sat Nov 30 23:43:46 +0000 2019
# created at: 2019-11-30 18:43:46
# Clean tweet: i dont know how to reiterate this anymore do not watch tdp on netflix amp do not hype it up not only because aaron doesn t
# i dont know how to reiterate this anymore do not watch tdp on netflix amp do not hype it up not only because aaron doesn t {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# polarity: 0
# userId: 1000976004746129409, userName: luis, userScreenName: lanceart
# user follower count: 56, userFollowing: False
# user friends count: 77
# text set: {'hype', 'doesn', 'do', 'tdp', 'amp', 'aaron', 'how', 'netflix', 'i', 'this', 'only', 'watch', 'anymore', 'dont', 'to', 'not', 'reiterate', 'it', 'on', 't', 'know', 'because', 'up'}
# Identifier: Netflix
# tweet found: True
# Lets begin to record! All the best :)
# latitude: None  logitude: None
# retweet count: 5
# faviourite count: 0
# hashtags: []
# Insert done!
# Inside tweet function
# Tweet started
# Retweet status: False
# Original tweet: If anyone need s me I’ll be in bed havin a stroke watching Netflix or something 😘😈
# created at: Sat Nov 30 23:43:28 +0000 2019
# created at: 2019-11-30 18:43:28
# Clean tweet: If anyone need s me Ill be in bed havin a stroke watching Netflix or something
# If anyone need s me Ill be in bed havin a stroke watching Netflix or something {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# polarity: 0
# userId: 3856422940, userName: Tim mann, userScreenName: Timmann4321
# user follower count: 297, userFollowing: False
# user friends count: 984
# text set: {'be', 'If', 'a', 'anyone', 'watching', 'bed', 'stroke', 'in', 'or', 'something', 'Netflix', 'Ill', 'havin', 'me', 's', 'need'}
# Identifier: Netflix
# tweet found: True
# Lets begin to record! All the best :)
# latitude: None  logitude: None
# retweet count: 0
# faviourite count: 0
# hashtags: []
# Insert done!
# Inside tweet function
# Tweet started
# Retweet status: False
# Original tweet: Hi I’m 5’8”, my favorite color is purple, I’m a psych major, I like to go out but I also like to stay in, i love mo… https://t.co/lAVRV5jhAD
# created at: Sat Nov 30 23:43:16 +0000 2019
# created at: 2019-11-30 18:43:16
# Clean tweet: Hi Im 58 my favorite color is purple Im a psych major I like to go out but I also like to stay in i love mo
# Hi Im 58 my favorite color is purple Im a psych major I like to go out but I also like to stay in i love mo {'neg': 0.0, 'neu': 0.61, 'pos': 0.39, 'compound': 0.9153}
# polarity: 1
# userId: 4923216614, userName: Ciara 💛, userScreenName: Dinahsaurclub
# user follower count: 177, userFollowing: False
# user friends count: 141
# text set: {'color', '58', 'stay', 'in', 'purple', 'is', 'also', 'psych', 'but', 'i', 'I', 'Hi', 'love', 'my', 'Im', 'to', 'like', 'favorite', 'mo', 'out', 'go', 'major', 'a'}
# Identifier: Netflix
# tweet found: False
# Lets begin to record! All the best :)
# latitude: None  logitude: None
# retweet count: 1
# faviourite count: 2
# hashtags: []
# ...
# Identifier: Netflix
# tweet found: True
# Lets begin to record! All the best :)
# latitude: None  logitude: None
# retweet count: 4
# faviourite count: 0
# hashtags: []
# Insert done!
# Inside tweet function
# Tweet started
# Retweet status: False
# Original tweet: RT @herbivore_club: The Game Changers, a Netflix documentary that explores the rise of veganism (or plant-based diets) amongst pro athletes…
# created at: Sat Nov 30 23:24:39 +0000 2019
# created at: 2019-11-30 18:24:39
# Clean tweet: The Game Changers a Netflix documentary that explores the rise of veganism or plant based diets amongst pro athletes
# The Game Changers a Netflix documentary that explores the rise of veganism or plant based diets amongst pro athletes {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# polarity: 0
# userId: 104618255, userName: Paula Schneider, userScreenName: pjschneid
# user follower count: 526, userFollowing: False
# user friends count: 676
# text set: {'the', 'athletes', 'Game', 'Netflix', 'amongst', 'plant', 'documentary', 'rise', 'Changers', 'of', 'pro', 'or', 'diets', 'based', 'veganism', 'explores', 'that', 'The', 'a'}
# Identifier: Netflix
# tweet found: True
# Lets begin to record! All the best :)
# latitude: None  logitude: None
# retweet count: 38
# faviourite count: 0
# hashtags: []
# Insert done!
# Inside tweet function
# Tweet started
# Retweet status: False
# Original tweet: RT @nicolexsolero: omg wait i just realized they are in the middle of filming shawn’s netflix documentary rn. do you think they got footage…
# created at: Sat Nov 30 23:24:32 +0000 2019
# created at: 2019-11-30 18:24:32
# Clean tweet: omg wait i just realized they are in the middle of filming shawns netflix documentary rn do you think they got footage
# omg wait i just realized they are in the middle of filming shawns netflix documentary rn do you think they got footage {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# polarity: 0
# userId: 1034208800780308480, userName: carol | FEEL BETTER SHAWN, userScreenName: getabitnervous
# user follower count: 105, userFollowing: False
# user friends count: 234
# text set: {'the', 'in', 'footage', 'do', 'filming', 'got', 'middle', 'documentary', 'just', 'you', 'shawns', 'realized', 'wait', 'netflix', 'i', 'of', 'are', 'rn', 'they', 'omg', 'think'}
# Identifier: Netflix
# tweet found: True
# Lets begin to record! All the best :)
# latitude: None  logitude: None
# retweet count: 4
# faviourite count: 0
# hashtags: []
# Insert done!
# Inside tweet function
# Tweet started
# Retweet status: False
# Original tweet: RT @AimanIAbdullah: I Netflix when I have lunch at work.
#
# For many of us, our jobs demand interaction with people/many people whether we li…
# created at: Sat Nov 30 23:24:03 +0000 2019
# created at: 2019-11-30 18:24:03
# Clean tweet: I Netflix when I have lunch at work For many of us our jobs demand interaction with people many people whether we li
# I Netflix when I have lunch at work For many of us our jobs demand interaction with people many people whether we li {'neg': 0.067, 'neu': 0.933, 'pos': 0.0, 'compound': -0.128}
# polarity: -1
# userId: 380377313, userName: ღ ns ღ, userScreenName: sya_elzara
# user follower count: 267, userFollowing: False
# user friends count: 190
# text set: {'when', 'Netflix', 'li', 'with', 'lunch', 'I', 'work', 'of', 'our', 'For', 'us', 'jobs', 'we', 'at', 'many', 'have', 'demand', 'whether', 'people', 'interaction'}
# Identifier: Netflix
# tweet found: True
# Lets begin to record! All the best :)
# latitude: None  logitude: None
# retweet count: 2408
# faviourite count: 0
# hashtags: []
# Insert done!
# Inside tweet function
# Tweet started
# Retweet status: False
# Original tweet: @lissijean I use the Netflix auto play example, cause literally everyone I know remembers that day that they didn’t… https://t.co/CHBoJCbDQ8
# created at: Sat Nov 30 23:23:24 +0000 2019
# created at: 2019-11-30 18:23:24
# Clean tweet: I use the Netflix auto play example cause literally everyone I know remembers that day that they didnt
# I use the Netflix auto play example cause literally everyone I know remembers that day that they didnt {'neg': 0.0, 'neu': 0.876, 'pos': 0.124, 'compound': 0.34}
# polarity: 1
# userId: 896105585099153408, userName: Trista April Taylor, userScreenName: trista_april
# user follower count: 10, userFollowing: False
# user friends count: 89
# text set: {'cause', 'the', 'example', 'auto', 'they', 'remembers', 'that', 'Netflix', 'day', 'didnt', 'know', 'play', 'everyone', 'use', 'I', 'literally'}
# Identifier: Netflix
# tweet found: True
# Lets begin to record! All the best :)
# latitude: None  logitude: None
# retweet count: 0
# faviourite count: 0
# hashtags: []
# Insert done!
# Inside tweet function
# Tweet started
# Retweet status: False
# Original tweet: @criterion if you release #TheIrishmanFilm with a bunch of kick ass extras or roundtables  I will absolutely buy it. @netflix
# created at: Sat Nov 30 23:23:04 +0000 2019
# created at: 2019-11-30 18:23:04
# Clean tweet: if you release TheIrishmanFilm with a bunch of kick ass extras or roundtables I will absolutely buy it
# if you release TheIrishmanFilm with a bunch of kick ass extras or roundtables I will absolutely buy it {'neg': 0.171, 'neu': 0.829, 'pos': 0.0, 'compound': -0.5423}
# polarity: -1
# userId: 1109922433056813057, userName: Inkylewetrust, userScreenName: inkylewetrust
# user follower count: 13, userFollowing: False
# user friends count: 172
# text set: {'of', 'you', 'bunch', 'buy', 'with', 'extras', 'or', 'absolutely', 'it', 'ass', 'TheIrishmanFilm', 'release', 'will', 'if', 'roundtables', 'I', 'a', 'kick'}
# Identifier: Netflix
# tweet found: False
# Lets begin to record! All the best :)
# latitude: None  logitude: None
# retweet count: 0
# faviourite count: 0
# hashtags: ['TheIrishmanFilm']
# Inside tweet function
# Tweet started
# Retweet status: False
# Original tweet: RT @StrikeSpectrum: Is this just incompetence or something nefarious?
#
# #YouTube TV Confirms Buffering Issue Affecting Spectrum Internet Use…
# created at: Sat Nov 30 23:23:00 +0000 2019
# created at: 2019-11-30 18:23:00
# Clean tweet: Is this just incompetence or something nefarious YouTube TV Confirms Buffering Issue Affecting Spectrum Internet Use
# Is this just incompetence or something nefarious YouTube TV Confirms Buffering Issue Affecting Spectrum Internet Use {'neg': 0.163, 'neu': 0.837, 'pos': 0.0, 'compound': -0.5106}
# polarity: -1
# userId: 864867145263534080, userName: Dwayne, userScreenName: stucky980
# user follower count: 276, userFollowing: False
# user friends count: 347
# text set: {'TV', 'Confirms', 'just', 'Use', 'incompetence', 'or', 'Issue', 'Is', 'something', 'Affecting', 'nefarious', 'Buffering', 'Spectrum', 'this', 'Internet', 'YouTube'}
# Identifier: Netflix
# tweet found: False
# Lets begin to record! All the best :)
# latitude: None  logitude: None
# retweet count: 9
# faviourite count: 0
# hashtags: ['YouTube']
# Inside tweet function
# Tweet started
# Retweet status: False
# Original tweet: RT @AlexandraErin: Apparently there is Discourse about whether it's respectful or not to pause The Irishman on Netflix and this is remindin…
# created at: Sat Nov 30 23:22:47 +0000 2019
# created at: 2019-11-30 18:22:47
# Clean tweet: Apparently there is Discourse about whether it s respectful or not to pause The Irishman on Netflix and this is remindin
# Apparently there is Discourse about whether it s respectful or not to pause The Irishman on Netflix and this is remindin {'neg': 0.0, 'neu': 0.875, 'pos': 0.125, 'compound': 0.4588}
# polarity: 1
# userId: 2459762905, userName: 📵🔨 adult-coded sex frog 📵🔨, userScreenName: oknolisten
# user follower count: 369, userFollowing: False
# user friends count: 129
# text set: {'Netflix', 'Discourse', 'remindin', 's', 'is', 'this', 'about', 'respectful', 'or', 'to', 'not', 'pause', 'on', 'it', 'Apparently', 'and', 'Irishman', 'whether', 'there', 'The'}
# Identifier: Netflix
# tweet found: True
# Lets begin to record! All the best :)
# latitude: None  logitude: None
# retweet count: 201
# faviourite count: 0
# hashtags: []
# Insert done!
# {'statuses': [{'created_at': 'Sat Nov 30 23:58:49 +0000 2019', 'id': 1200927193448079362, 'id_str': '1200927193448079362', 'text': 'RT @AimanIAbdullah: I Netflix when I have lunch at work.\n\nFor many of us, our jobs demand interaction with people/many people whether we li…', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'AimanIAbdullah', 'name': 'Aiman I.', 'id': 122611718, 'id_str': '122611718', 'indices': [3, 18]}], 'urls': []}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 495700546, 'id_str': '495700546', 'name': 'Golden Recipe', 'screen_name': 'AisyahSyarip', 'location': 'Sabahan', 'description': 'UMS and i love foods better than myself periodt', 'url': 'https://t.co/oUbWremcSy', 'entities': {'url': {'urls': [{'url': 'https://t.co/oUbWremcSy', 'expanded_url': 'http://aisyahsyarip.blogspot.com', 'display_url': 'aisyahsyarip.blogspot.com', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 422, 'friends_count': 1130, 'listed_count': 6, 'created_at': 'Sat Feb 18 07:03:41 +0000 2012', 'favourites_count': 5132, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': False, 'statuses_count': 61570, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'FF6699', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme11/bg.gif', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme11/bg.gif', 'profile_background_tile': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1158616240316768258/TycMFq0m_normal.png', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1158616240316768258/TycMFq0m_normal.png', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/495700546/1565070759', 'profile_link_color': 'B40B44', 'profile_sidebar_border_color': 'FFFFFF', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': True, 'default_profile': False, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Thu Nov 28 16:57:51 +0000 2019', 'id': 1200096475667001345, 'id_str': '1200096475667001345', 'text': 'I Netflix when I have lunch at work.\n\nFor many of us, our jobs demand interaction with people/many people whether w… https://t.co/F3eZAqS8Py', 'truncated': True, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/F3eZAqS8Py', 'expanded_url': 'https://twitter.com/i/web/status/1200096475667001345', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [117, 140]}]}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 122611718, 'id_str': '122611718', 'name': 'Aiman I.', 'screen_name': 'AimanIAbdullah', 'location': 'Kuala Lumpur, Malaysia', 'description': 'A funny guy. I mean I crack myself up all the time. | Managing Editor at https://t.co/iDnTCw3uTn, and former Associate Editor at CarShowroom Australia', 'url': 'https://t.co/Mwt9XmB1IZ', 'entities': {'url': {'urls': [{'url': 'https://t.co/Mwt9XmB1IZ', 'expanded_url': 'https://www.youtube.com/c/MalaysianMotoring', 'display_url': 'youtube.com/c/MalaysianMot…',  ...
# [{'created_at': 'Sat Nov 30 23:58:49 +0000 2019', 'text': 'RT @AimanIAbdullah: I Netflix when I have lunch at work.\n\nFor many of us, our jobs demand interaction with people/many people whether we li…', 'user': 'AisyahSyarip'}, {'created_at': 'Sat Nov 30 23:58:07 +0000 2019', 'text': 'What’s some good shows to watch on Netflix or Hulu', 'user': 'Lullsav'}, {'created_at': 'Sat Nov 30 23:57:26 +0000 2019', 'text': 'RT @SwedishLincoln: Hey @netflix quick question, did you forget to include the after credits scene of The Irishman or something?', 'user': 'laserpants2'}, {'created_at': 'Sat Nov 30 23:57:09 +0000 2019', 'text': 'RT @SarahJKozak: My local newspaper from yesterday💞 we will NOT go unheard or go down WITHOUT a fight !!!! @netflix @Netflixhelps @northwoo…', 'user': 'booksnhallmark'}, {'created_at': 'Sat Nov 30 23:56:27 +0000 2019', 'text': 'I want a dog so it could cuddle with me whenever I’m working on something or watching Netflix 😩💕🐶', 'user': 'chingona25'}, {'created_at': 'Sat Nov 30 23:56:04 +0000 2019', 'text': "RT @sun_shine_sonja: If you make #Lucifer #MoreThan5Seasons I am sure Tom Ellis or Lauren German will get an Emmy for it. Don't you wanna k…", 'user': 'Soredamor42'}, {'created_at': 'Sat Nov 30 23:55:29 +0000 2019', 'text': 'Pitch perfect 3 is on the uk Netflix now so best believe am watching that instead of packing or sleeping and I have… https://t.co/TiEffi1Td2', 'user': 'kelley_brohara'}, {'created_at': 'Sat Nov 30 23:55:21 +0000 2019', 'text': 'Is Snapped on Netflix or Hulu or anywhere', 'user': 'DuhItzMiaaaa'}, {'created_at': 'Sat Nov 30 23:55:06 +0000 2019', 'text': 'RT @TeamRomany: "Holiday Rush" is Trending on Netflix and it\'s About Time. “I love that we\'re telling a story about a black, single father…', 'user': 'Jauthor12'}, {'created_at': 'Sat Nov 30 23:55:02 +0000 2019', 'text': 'Just me , or us @netflix gotten even more impatient with the “are you still there” pause ........', 'user': 'djmorse126'}, {'created_at': 'Sat Nov 30 23:55:01 +0000 2019', 'text': "@thesamwisest Yes, I've had trouble accessing Netflix on my phone sporadically for the last 3 or 4 days now. My lis… https://t.co/RVJSBNHI8C", 'user': 'Tusker2Zero'}, {'created_at': 'Sat Nov 30 23:53:42 +0000 2019', 'text': 'Anyone have recommendations for good suspense movies or shows on Netflix?', 'user': 'indeIIible'}, {'created_at': 'Sat Nov 30 23:53:32 +0000 2019', 'text': "RT @CanoAwae: I really want to wake up one day with news that our show has been renewed. Wheter it's Netflix or any other network really. #…", 'user': 'booksnhallmark'}, {'created_at': 'Sat Nov 30 23:53:32 +0000 2019', 'text': 'A.) Chose the wrong time for a movie like someone with ADD \n2.) NOT a Scorsese fan and watched for trending purpose… https://t.co/Ce4xIZeFwl', 'user': 'YomamaluvnRomeo'}, {'created_at': 'Sat Nov 30 23:53:26 +0000 2019', 'text': 'RT @patriotgirl5: 666 is the MAGIC number. If every Lucifriend tweets or RTs 666 times to save LUCIFER today – we will trend on Twitter! We…', 'user': 'Siwckc'}, {'created_at': 'Sat Nov 30 23:53:23 +0000 2019', 'text': 'RT @TeamRomany: "Holiday Rush" is Trending on Netflix and it\'s About Time. “I love that we\'re telling a story about a black, single father…', 'user': 'FTL18Julia'}, {'created_at': 'Sat Nov 30 23:52:17 +0000 2019', 'text': 'This #bikram #yoga documentary on @netflix is insane. If you’ve ever done bikram yoga or were hoping to attend a te… https://t.co/quKIg14JYi', 'user': 'fonziewonzie'}, {'created_at': 'Sat Nov 30 23:51:56 +0000 2019', 'text': 'RT @Macys: Sam and Guy’s hammobile on @netflix’s Green Eggs and Ham balloon is big enough to fit 4 million eggs or 14,000 hams. #macysparad…', 'user': 'Lecus5'}, {'created_at': 'Sat Nov 30 23:51:51 +0000 2019', 'text': 'Netflix suggestions? ... or should I say fuck it and cop the Disney+ ?.. decisions ⛪️ .', 'user': 'OhMyGodGRAM'}, {'created_at': 'Sat Nov 30 23:51:51 +0000 2019', 'text': '@ShadowBriton @CMCoys Sky or streams they took it off Netflix😭😭😭', 'user ...

# %% [markdown]
# ## Extra

# %%
# def big_func():
    
#     def trial_score_check(text):
    
#         analyser11 = SentimentIntensityAnalyzer()
#         tt_score = analyser11.polarity_scores(text)
#         return tt_score
#     fd_vader = pd.DataFrame(data=['good','bad','fair','plain','so','night'], columns = ["Word"]).drop([0]).reindex()
#     fd_vader['Compound_Score'] = fd_vader['Word'].apply(trial_score_check)
#     print(fd_vader['Compound_Score'])
    
# big_func()

# %%
# def trial_score_check(text):
    
#         analyser11 = SentimentIntensityAnalyzer()
#         tt_score = analyser11.polarity_scores(text)
#         return tt_score['compound']

# fd_vader = pd.DataFrame(data=['good','bad','fair','plain','so','night'], columns = ["Word"]).drop([0]).reindex()
# fd_vader['Compound_Score'] = fd_vader['Word'].apply(trial_score_check)
# fd_vader['Compound_Score']#[1]
