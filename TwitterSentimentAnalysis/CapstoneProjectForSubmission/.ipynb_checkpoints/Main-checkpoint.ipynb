# %%
import credentials
import twitter_settings  
import imp 
imp.reload(twitter_settings)
imp.reload(credentials)
from twitter_settings import *
import re
import tweepy
import mysql.connector
import pandas as pd
import numpy as np
#from textblob import TextBlob
from nltk.sentiment.vader import SentimentIntensityAnalyzer
import json

# %% [markdown]
# - positive sentiment: compound score >= 0.05
# - neutral sentiment: (compound score > -0.05) and (compound score < 0.05)
# - negative sentiment: compound score <= -0.05

# %%
class MyStreamListener(tweepy.StreamListener):
    def on_connect(self):
        # Called initially to connect to the Streaming API
        print("You are now connected to the streaming API.")
        
    def on_status(self,status):
  
        print("Tweet started")
        
        print('Retweet status: {0}'.format(status.retweeted))
        print('Original tweet: {0}'.format(status.text))
        
        if status.retweeted:
            ## for now avoid retweeted info
            return True

        #Extract attributes of each tweet
        id_str=status.id_str
        created_at=status.created_at
        print("Created at: {0}".format(created_at))
        original_text=status.text
        text=deEmojify_tweet(status.text)
        text=clean_tweet(text)

        print('Clean tweet: {0}'.format(text))
        
        ## use Vader to check sentiment of text
        ########################################
        analyser = SentimentIntensityAnalyzer()
        
        score = analyser.polarity_scores(status.text)
        print("{:-<40} \n {}".format(text, str(score)))
        
        if score['compound']>=0.05: #positive
            polarity = 1
        elif (score['compound']>-0.05) & (score['compound']<0.05): #neutral
            polarity = 0
        elif score['compound']<=-0.05: #negative
            polarity = -1
            
        compound_score=score['compound']
        positive_score=score['pos']
        negative_score=score['neg']
        neutral_score=score['neu']
        print('polarity: {0}'.format(polarity))
        
        ## set subjectivity as 0 for Vader
        subjectivity = 0
        ###########################################
        
        ## use TextBlob to check sentiment of text
        ########################################
#         sentiment=TextBlob(text).sentiment
#         polarity=sentiment.polarity
#         subjectivity=sentiment.subjectivity
        ######################################
        
       
        
        hashtags = []   #make an empty list

        for hashtag in status.entities['hashtags']:    #iterate over the list
            hashtags.append(hashtag["text"])             #append each hashtag to 'hashtags'

        print('hashtags: {0}'.format(str(hashtags)))
        #usermentions_list = json.dump(user_mentions)
        user_id = status.user.id_str
        user_name = status.user.name
        user_screen_name = status.user.screen_name
        print('userId: {0}, userName: {1}, userScreenName: {2}'.format(user_id,user_name,user_screen_name))
        user_created_at = status.user.created_at
        user_location=deEmojify_tweet(status.user.location)
        user_description=deEmojify_tweet(status.user.description)
        
        user_friends_count = status.user.friends_count
        user_followers_count=status.user.followers_count
        user_following = status.user.following
        print('user follower count: {0}, userFollowing: {1}'.format(user_followers_count,user_following))
        print('user friends count: {0}'.format(user_friends_count))
        
        #------------------------------------------
        tweetFound=False
        track_val = ''
        tweet_found_count = 0
        
        netflix_check_list = ['Netflix','netflix']
        netflix_check_set = set(netflix_check_list)
#         appletv_check_list = ['AppleTV','Apple TV','appletv','apple tv']
#         appletv_check_set = set(appletv_check_list)
#         disney_check_list = ['DisneyPlus','Disney+','disneyplus','disney+','disney','Disney','Disneyplus']
#         disney_check_set = set(disney_check_list)
#         amazon_check_list = ['Amazon Prime Video','amazon prime video','AmazonPrimeVideo',
#                      'amazonprimevideo','AmazonPrime Video','Amazon Prime','amazon prime','amazon','prime',
#                     'Amazon','Prime']
#         amazon_check_set = set(amazon_check_list)
# #         hbo_check_list = ['HBOMax','HBO Max','hbomax']
# #         hbo_check_set = set(hbo_check_list)

        text_set = set(text.split())
#         if amazon_check_set.intersection(text_set):
#             track_val = 'AmazonPrime'
#             tweetFound=True
#             tweet_found_count = tweet_found_count + 1
#         if appletv_check_set.intersection(text_set):
#             track_val = 'AppleTV'
#             tweetFound=True
#             tweet_found_count = tweet_found_count + 1
#         if disney_check_set.intersection(text_set):
#             track_val = 'DisneyPlus'
#             tweetFound=True
#             tweet_found_count = tweet_found_count + 1
# #         if hbo_check_set.intersection(text_set):
# #             track_val = 'HBOmax'
# #             tweetFound=True
# #             tweet_found_count = tweet_found_count + 1
        if netflix_check_set.intersection(text_set):
            track_val = 'Netflix'
            tweetFound=True
            tweet_found_count = tweet_found_count + 1
        
        if (tweet_found_count > 1):
            tweetFound = False
        
        print("Lets begin to record! All the best :)")
        
        longitude=None
        latitude=None
        if status.coordinates:
            longitude=status.coordinates['coordinates'][0]
            latitude=status.coordinates['coordinates'][1]
            
        retweet_count=status.retweet_count
        favorite_count=status.favorite_count
        
        
        
        print('latitude: {0}  logitude: {1}'.format(latitude,longitude))
        
        
        if tweetFound:
            if mydb.is_connected():
                mycursor=mydb.cursor()

                sql = "INSERT IGNORE INTO {} (id_str, created_at, track ,text, original_text, polarity, compound_score, negative_score, positive_score, neutral_score,subjectivity, hashtags,\
                user_created_at, user_id, user_name, user_screen_name,\
                user_location, user_description, user_followers_count, user_friends_count, longitude, latitude, retweet_count, favorite_count) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s ,%s, %s, %s, %s, %s, %s, %s, %s, %s, %s)".format(twitter_settings.TABLE_NAME)
                val = (id_str, created_at, track_val, text, original_text, polarity, compound_score, negative_score, positive_score, neutral_score ,subjectivity, str(hashtags), user_created_at, user_id, user_name, user_screen_name, user_location, \
                    user_description, user_followers_count, user_friends_count, longitude, latitude, retweet_count, favorite_count)
                mycursor.execute(sql, val)
                mydb.commit()
                mycursor.close()
        
    def on_error(self, status_code):
        
        ##Since Twitter API has rate limits, stop srcraping data as it exceed to the thresold.
        
        if status_code == 420:
            # return False to disconnect the stream
            return False

# %%
def clean_tweet(tweet): 
     
    ##Use sumple regex statemnents to clean tweet text by removing links and special characters
    
    tweet_text= ' '.join(re.sub("(RT @[\w_]+:)|(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)", " ", tweet).split()) 
    tweet_text = re.sub(r'(.)\1{2,}',r'\1\1',tweet_text)
    return tweet_text

def deEmojify_tweet(text):
    
    ##Strip all non-ASCII characters to remove emoji characters
    
    if text:
        return text.encode('ascii', 'ignore').decode('ascii')
    else:
        return None

# %%
mydb = mysql.connector.connect(
    host="localhost",
    user="root",
    password="*******",
    database="TwitterDB",
    auth_plugin='mysql_native_password',
    charset='utf8'
    
)
if mydb.is_connected():
    mycursor = mydb.cursor()
    mycursor.execute("SELECT COUNT(*) FROM information_schema.tables where table_name='{0}'".
                     format(twitter_settings.TABLE_NAME))
if mycursor.fetchone()[0] != 1:
    mycursor.execute("CREATE TABLE {} ({})".format(twitter_settings.TABLE_NAME, twitter_settings.TABLE_ATTRIBUTES))
    mydb.commit()
    mycursor.close()

# %%
auth  = tweepy.OAuthHandler(credentials.API_KEY, credentials.API_SECRET_KEY)
auth.set_access_token(credentials.ACCESS_TOKEN, credentials.ACCESS_TOKEN_SECRET)
api = tweepy.API(auth)

# %%
myStreamListener = MyStreamListener()
myStream = tweepy.Stream(auth = api.auth, listener = myStreamListener)
myStream.filter(languages=["en"], track = twitter_settings.TRACK_WORDS)
# Close the MySQL connection as it finished
# However, this won't be reached as the stream listener won't stop automatically
# Press STOP button to finish the process.
mydb.close()
# Out:
# You are now connected to the streaming API.
# Tweet started
# Retweet status: False
# Original tweet: Two weeks in a row now I’ve tried to watch #JackRyan  but I think @PrimeVideo needs more servers - constant  buffer… https://t.co/9QRzuBnAY9
# Created at: 2019-12-03 02:49:42
# Clean tweet: Two weeks in a row now Ive tried to watch JackRyan but I think needs more servers constant buffer
# Two weeks in a row now Ive tried to watch JackRyan but I think needs more servers constant buffer
#  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# polarity: 0
# hashtags: ['JackRyan']
# userId: 708973, userName: petulantMarmot, userScreenName: tendancer
# user follower count: 304, userFollowing: False
# user friends count: 98
# Lets begin to record! All the best :)
# latitude: None  logitude: None
# Tweet started
# Retweet status: False
# Original tweet: RT @AwaeYou: Ok, real talk, I’m a tv buff. I love stranger things, outlander, the crown, etc. But you could cancel any one of those shows a…
# Created at: 2019-12-03 02:49:44
# Clean tweet: Ok real talk Im a tv buff I love stranger things outlander the crown etc But you could cancel any one of those shows a
# Ok real talk Im a tv buff I love stranger things outlander the crown etc But you could cancel any one of those shows a
#  {'neg': 0.066, 'neu': 0.724, 'pos': 0.211, 'compound': 0.6597}
# polarity: 1
# hashtags: []
# userId: 956983717528039424, userName: Julia with an A, userScreenName: JulMal5
# user follower count: 109, userFollowing: False
# user friends count: 136
# Lets begin to record! All the best :)
# latitude: None  logitude: None
# Tweet started
# Retweet status: False
# Original tweet: RT @wordtodanny: Netflix got Malcolm X, they not playing
# Created at: 2019-12-03 02:49:44
# Clean tweet: Netflix got Malcolm X they not playing
# Netflix got Malcolm X they not playing--
#  {'neg': 0.166, 'neu': 0.834, 'pos': 0.0, 'compound': -0.1511}
# polarity: -1
# hashtags: []
# userId: 2972293876, userName: Toni., userScreenName: ToniCaltrice_
# user follower count: 135, userFollowing: False
# user friends count: 136
# Lets begin to record! All the best :)
# latitude: None  logitude: None
# Tweet started
# Retweet status: False
# Original tweet: RT @Dehkunle: Logged in Netflix now and I’m seeing so many Nigerian movies ,Nigerian movie directors and producers have broken the rules an…
# Created at: 2019-12-03 02:49:45
# Clean tweet: Logged in Netflix now and Im seeing so many Nigerian movies Nigerian movie directors and producers have broken the rules an
# Logged in Netflix now and Im seeing so many Nigerian movies Nigerian movie directors and producers have broken the rules an
#  {'neg': 0.124, 'neu': 0.876, 'pos': 0.0, 'compound': -0.4767}
# polarity: -1
# hashtags: []
# userId: 1118091501286973442, userName: Swagzburna, userScreenName: SchoolBoyOG
# user follower count: 174, userFollowing: False
# user friends count: 196
# Lets begin to record! All the best :)
# latitude: None  logitude: None
# Tweet started
# Retweet status: False
# Original tweet: oh god
# Created at: 2019-12-03 02:49:45
# Clean tweet: oh god
# oh god----------------------------------
#  {'neg': 0.0, 'neu': 0.323, 'pos': 0.677, 'compound': 0.2732}
# polarity: 1
# hashtags: []
# userId: 830912608677003264, userName: 𝘫𝘰𝘯𝘨𝘩𝘰'𝘴 𝘴𝘵𝘢𝘳 𝘪𝘣𝘣𝘺 ♡, userScreenName: lesbianjinki
# user follower count: 978, userFollowing: False
# user friends count: 130
# Lets begin to record! All the best :)
# latitude: None  logitude: None
# Tweet started
# Retweet status: False
# Original tweet: RT @chanyeoldaily: chanyeol for netflix https://t.co/xEMA1UxRmL
# Created at: 2019-12-03 02:49:45
# Clean tweet: chanyeol for netflix
# chanyeol for netflix--------------------
#  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# polarity: 0
# hashtags: []
# userId: 405392498, userName: 크리스탈, userScreenName: kjnep1016
# user follower count: 232, userFollowing: False
# user friends count: 400
# Lets begin to record! All the best :)
# latitude: None  logitude: None
# Tweet started
# Retweet status: False
# Original tweet: END OF WATCH IS BACK ON NETFLIX 😅
# Created at: 2019-12-03 02:49:45
# Clean tweet: END OF WATCH IS BACK ON NETFLIX
# END OF WATCH IS BACK ON NETFLIX---------
#  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# polarity: 0
# hashtags: []
# userId: 554161389, userName: Kim 🌹, userScreenName: _kimbo___
# user follower count: 263, userFollowing: False
# user friends count: 178
# Lets begin to record! All the best :)
# latitude: None  logitude: None
# Tweet started
# Retweet status: False
# Original tweet: RT @classymommy: The Netflix Original hit series, DreamWorks Spirit Riding Free is a favorite!
#
# Check out our video demo of the Spirit Gro…
# Created at: 2019-12-03 02:49:46
# Clean tweet: The Netflix Original hit series DreamWorks Spirit Riding Free is a favorite Check out our video demo of the Spirit Gro
# The Netflix Original hit series DreamWorks Spirit Riding Free is a favorite Check out our video demo of the Spirit Gro
#  {'neg': 0.0, 'neu': 0.58, 'pos': 0.42, 'compound': 0.8832}
# polarity: 1
# hashtags: []
# userId: 255310849, userName: OB1, userScreenName: yoda1librarian
# user follower count: 2665, userFollowing: False
# user friends count: 4998
# Lets begin to record! All the best :)
# latitude: None  logitude: None
# Tweet started
# Retweet status: False
# Original tweet: RT @ignacio_aries: what i want to watch:
#
# ⚪sunset
# ⚪netflix
# 🔘you while smiling
# Created at: 2019-12-03 02:49:46
# Clean tweet: what i want to watch sunset netflix you while smiling
# what i want to watch sunset netflix you while smiling
#  {'neg': 0.0, 'neu': 0.677, 'pos': 0.323, 'compound': 0.5106}
# polarity: 1
# hashtags: []
# userId: 1173211531212808193, userName: imagoodgirl, userScreenName: asyasaffiya1
# user follower count: 125, userFollowing: False
# user friends count: 107
# Lets begin to record! All the best :)
# latitude: None  logitude: None
# Tweet started
# Retweet status: False
# Original tweet: Oliver! 🏹
# Created at: 2019-12-03 02:49:46
# Clean tweet: Oliver
# Oliver----------------------------------
#  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# polarity: 0
# hashtags: []
# userId: 232354452, userName: Tonny Coronado, userScreenName: Tonny_Coronado
# user follower count: 419, userFollowing: False
# user friends count: 371
# Lets begin to record! All the best :)
# latitude: None  logitude: None
# Tweet started
# Retweet status: False
# Original tweet: Netflix: Bring Back Merlin - Sign the Petition! https://t.co/gsEQ9gXOp6 via @UKChange
# Created at: 2019-12-03 02:49:46
# Clean tweet: Netflix Bring Back Merlin Sign the Petition via
# Netflix Bring Back Merlin Sign the Petition via
#  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# polarity: 0
# hashtags: []
# userId: 1142173026580148224, userName: ArEyOuDuMb, userScreenName: ArEyOuD70425856
# user follower count: 0, userFollowing: False
# user friends count: 9
# Lets begin to record! All the best :)
# latitude: None  logitude: None
# Tweet started
# Retweet status: False
# Original tweet: Anthony Edward Stark.
# Created at: 2019-12-03 02:49:50
# Clean tweet: Anthony Edward Stark
# Anthony Edward Stark--------------------
#  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# polarity: 0
# hashtags: []
# userId: 113995472, userName: Mr. Freaka, userScreenName: Freakspaulding
# user follower count: 1376, userFollowing: False
# user friends count: 1127
# Lets begin to record! All the best :)
# latitude: None  logitude: None
# Tweet started
# Retweet status: False
# Original tweet: Frank Sheeran
# Created at: 2019-12-03 02:49:51
# Clean tweet: Frank Sheeran
# Frank Sheeran---------------------------
#  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# polarity: 0
# hashtags: []
# userId: 334913666, userName: Camilo Guerra Téllez, userScreenName: camiloguerrat
# user follower count: 236, userFollowing: False
# user friends count: 1032
# Lets begin to record! All the best :)
# latitude: None  logitude: None
# Tweet started
# Retweet status: False
# Original tweet: Real MVP #awaeseason4 #renewannewithane @hellosunshine @northwoodenter @YoWalleyB @MirandadeP
# Created at: 2019-12-03 02:49:51
# Clean tweet: Real MVP awaeseason4 renewannewithane
# Real MVP awaeseason4 renewannewithane---
#  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# polarity: 0
# hashtags: ['awaeseason4', 'renewannewithane']
# userId: 1199065368972713987, userName: Mia McKenzie, userScreenName: MiaMcKenzie1
# user follower count: 176, userFollowing: False
# user friends count: 371
# Lets begin to record! All the best :)
# latitude: None  logitude: None
# Tweet started
# Retweet status: False
# Original tweet: Dolly Parton’s Heartstrings on Netflix is a must 🌻🦋😢💓
# Created at: 2019-12-03 02:49:52
# Clean tweet: Dolly Partons Heartstrings on Netflix is a must
# Dolly Partons Heartstrings on Netflix is a must
#  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# polarity: 0
# hashtags: []
# userId: 1111404135239335936, userName: kaylin elizabeth, userScreenName: kaylinp_32
# user follower count: 34, userFollowing: False
# user friends count: 83
# Lets begin to record! All the best :)
# latitude: None  logitude: None
# Tweet started
# Retweet status: False
# Original tweet: ‘In the dark’ on Netflix is such a good ass show.
# Created at: 2019-12-03 02:49:52
# Clean tweet: In the dark on Netflix is such a good ass show
# In the dark on Netflix is such a good ass show
#  {'neg': 0.243, 'neu': 0.556, 'pos': 0.201, 'compound': -0.1531}
# polarity: -1
# hashtags: []
# userId: 2404994355, userName: Jenaè, userScreenName: jenaelovee
# user follower count: 239, userFollowing: False
# user friends count: 131
# Lets begin to record! All the best :)
# latitude: None  logitude: None
# Tweet started
# Retweet status: False
# Original tweet: RT @MerleDandridge: Errrmegerrrrrd! One week until Season 4 of @greenleafown is on @netflix Gaaaaahhh! So excited! #Greenleaf https://t.co/…
# Created at: 2019-12-03 02:49:53
# Clean tweet: Errmegerrd One week until Season 4 of is on Gaahh So excited Greenleaf
# Errmegerrd One week until Season 4 of is on Gaahh So excited Greenleaf
#  {'neg': 0.0, 'neu': 0.818, 'pos': 0.182, 'compound': 0.5528}
# polarity: 1
# hashtags: ['Greenleaf']
# userId: 1340618102, userName: Humble Beast 🤭💨😈, userScreenName: aintyoutay1
# user follower count: 895, userFollowing: False
# user friends count: 934
# Lets begin to record! All the best :)
# latitude: None  logitude: None
# Tweet started
# Retweet status: False
# Original tweet: Friends and The West Wing are both about to be removed from @netflix so that might also mean the end of our subscription. #fail
# Created at: 2019-12-03 02:49:53
# Clean tweet: Friends and The West Wing are both about to be removed from so that might also mean the end of our subscription fail
# Friends and The West Wing are both about to be removed from so that might also mean the end of our subscription fail
#  {'neg': 0.0, 'neu': 0.881, 'pos': 0.119, 'compound': 0.4767}
# polarity: 1
# hashtags: ['fail']
# userId: 20539447, userName: Nicole Justis Ubben, userScreenName: NicoleUbben
# user follower count: 482, userFollowing: False
# user friends count: 1045
# Lets begin to record! All the best :)
# latitude: None  logitude: None
# Tweet started
# Retweet status: False
# Original tweet: @lodgepolepines Just watched a Netflix show on this.  It's capitalism's fault. China was offering better prices for… https://t.co/BMYgvmbNLr
# Created at: 2019-12-03 02:49:54
# Clean tweet: Just watched a Netflix show on this It s capitalism s fault China was offering better prices for
# Just watched a Netflix show on this It s capitalism s fault China was offering better prices for
#  {'neg': 0.131, 'neu': 0.728, 'pos': 0.141, 'compound': 0.0516}
# polarity: 1
# hashtags: []
# userId: 980229866548178944, userName: 🔺 Bring on the revolution✊, userScreenName: 808Progressive
# user follower count: 248, userFollowing: False
# user friends count: 321
# Lets begin to record! All the best :)
# latitude: None  logitude: None
# Tweet started
# Retweet status: False
# Original tweet: I forgot they dropped Malcolm X on Netflix. 🖤
# Created at: 2019-12-03 02:49:55
# Clean tweet: I forgot they dropped Malcolm X on Netflix
# I forgot they dropped Malcolm X on Netflix
#  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# polarity: 0
# hashtags: []
# userId: 224521657, userName: ju, userScreenName: ColorStruckLove
# user follower count: 1043, userFollowing: False
# user friends count: 1092
# Lets begin to record! All the best :)
# latitude: None  logitude: None
# Tweet started
# Retweet status: False
# Original tweet: RT @InqEnt: EXO fans, show your LOVE! More from #EXO at #6Underground premiere @InqEnt @Netflix @netflixPH #Uppercut #netflixfilm #exofans…
# Created at: 2019-12-03 02:49:55
# Clean tweet: EXO fans show your LOVE More from EXO at 6Underground premiere Uppercut netflixfilm exofans
# EXO fans show your LOVE More from EXO at 6Underground premiere Uppercut netflixfilm exofans
#  {'neg': 0.0, 'neu': 0.775, 'pos': 0.225, 'compound': 0.7371}
# polarity: 1
# hashtags: ['EXO', '6Underground', 'Uppercut', 'netflixfilm', 'exofans']
# userId: 1196700475761889280, userName: Loeychan27, userScreenName: Luv12348
# user follower count: 0, userFollowing: False
# user friends count: 36
# Lets begin to record! All the best :)
# latitude: None  logitude: None
# Tweet started
# Retweet status: False
# Original tweet: RT @beltanegoddess: CBC, Netflix: guys the show it's officially cancelled, stop tweeting
#
# Us:
#
# #renewannewithane
#
# https://t.co/Sp0UY2p35S
# Created at: 2019-12-03 02:49:55
# Clean tweet: CBC Netflix guys the show it s officially cancelled stop tweeting Us renewannewithane
# CBC Netflix guys the show it s officially cancelled stop tweeting Us renewannewithane
#  {'neg': 0.244, 'neu': 0.756, 'pos': 0.0, 'compound': -0.4939}
# polarity: -1
# hashtags: ['renewannewithane']
# userId: 1001465722810388483, userName: marizinha SAVE ANNE WITH AN E, userScreenName: soundslikemari
# user follower count: 99, userFollowing: False
# user friends count: 177
# Lets begin to record! All the best :)
# latitude: None  logitude: None
# Tweet started
# Retweet status: False
# Original tweet: @hartsandhelbig @sawyerscazzie It is SO GOOD!!! If you have Netflix I highly suggest it!
# Created at: 2019-12-03 02:49:55
# Clean tweet: It is SO GOOD If you have Netflix I highly suggest it
# It is SO GOOD If you have Netflix I highly suggest it
#  {'neg': 0.0, 'neu': 0.673, 'pos': 0.327, 'compound': 0.78}
# polarity: 1
# hashtags: []
# userId: 1118313237613826049, userName: ♥ 🎃, userScreenName: Lei_loeux
# user follower count: 13, userFollowing: False
# user friends count: 197
# Lets begin to record! All the best :)
# latitude: None  logitude: None
# Tweet started
# Retweet status: False
# Original tweet: RT @ignacio_aries: what i want to watch:
#
# ⚪sunset
# ⚪netflix
# 🔘you while smiling
# Created at: 2019-12-03 02:49:55
# Clean tweet: what i want to watch sunset netflix you while smiling
# what i want to watch sunset netflix you while smiling
#  {'neg': 0.0, 'neu': 0.677, 'pos': 0.323, 'compound': 0.5106}
# polarity: 1
# hashtags: []
# userId: 1069527707044597762, userName: Amirul Ashraff, userScreenName: amirulashhhh
# user follower count: 77, userFollowing: False
# user friends count: 63
# Lets begin to record! All the best :)
# latitude: None  logitude: None
# Tweet started
# Retweet status: False
# Original tweet: your name de volta na netflix https://t.co/REpM2tPQJ5
# Created at: 2019-12-03 02:49:56
# Clean tweet: your name de volta na netflix
# your name de volta na netflix-----------
#  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# polarity: 0
# hashtags: []
# userId: 528925629, userName: ㄹizz, userScreenName: peachlizz
# user follower count: 621, userFollowing: False
# user friends count: 472
# Lets begin to record! All the best :)
# latitude: None  logitude: None
# Tweet started
# Retweet status: False
# Original tweet: RT @bugheadshirbert: I'm going to delete my @netflix account and cry for the rest of my life #renewannewithane (drama queen) https://t.co/e…
# Created at: 2019-12-03 02:49:56
# Clean tweet: I m going to delete my account and cry for the rest of my life renewannewithane drama queen
# I m going to delete my account and cry for the rest of my life renewannewithane drama queen
#  {'neg': 0.134, 'neu': 0.866, 'pos': 0.0, 'compound': -0.4767}
# polarity: -1
# hashtags: ['renewannewithane']
# userId: 834892575106478080, userName: Yessi, userScreenName: Yessi99140504
# user follower count: 53, userFollowing: False
# user friends count: 32
# Lets begin to record! All the best :)
# latitude: None  logitude: None
# Tweet started
# Retweet status: False
# Original tweet: RT @andoviews: Everybody hates Chris needs to be on Netflix
# Created at: 2019-12-03 02:49:56
# Clean tweet: Everybody hates Chris needs to be on Netflix
# Everybody hates Chris needs to be on Netflix
#  {'neg': 0.244, 'neu': 0.756, 'pos': 0.0, 'compound': -0.4404}
# polarity: -1
# hashtags: []
# userId: 102319953, userName: riri, userScreenName: riannagalorex
# user follower count: 844, userFollowing: False
# user friends count: 571
# Lets begin to record! All the best :)
# latitude: None  logitude: None
# Tweet started
# Retweet status: False
# Original tweet: RT @goodbeanalt: shes laying in his king sized bed, watching Netflix. she sees your text. she ignores it and puts her phone on do not distu…
# Created at: 2019-12-03 02:49:57
# Clean tweet: shes laying in his king sized bed watching Netflix she sees your text she ignores it and puts her phone on do not distu
# shes laying in his king sized bed watching Netflix she sees your text she ignores it and puts her phone on do not distu
#  {'neg': 0.077, 'neu': 0.923, 'pos': 0.0, 'compound': -0.2732}
# polarity: -1
# hashtags: []
# userId: 3040037459, userName: Abby Curry🌙☮️, userScreenName: abbyismyname_8
# user follower count: 226, userFollowing: False
# user friends count: 93
# Lets begin to record! All the best :)
# latitude: None  logitude: None
# Tweet started
# Retweet status: False
# Original tweet: RT @ignacio_aries: what i want to watch:
#
# ⚪sunset
# ⚪netflix
# 🔘you while smiling
# Created at: 2019-12-03 02:49:57
# Clean tweet: what i want to watch sunset netflix you while smiling
# what i want to watch sunset netflix you while smiling
#  {'neg': 0.0, 'neu': 0.677, 'pos': 0.323, 'compound': 0.5106}
# polarity: 1
# hashtags: []
# userId: 1091732179845971969, userName: faiqah, userScreenName: fqhabriyah
# user follower count: 48, userFollowing: False
# user friends count: 80
# Lets begin to record! All the best :)
# latitude: None  logitude: None
# Tweet started
# Retweet status: False
# Original tweet: RT @laurelnation: @MzKatieCassidy ik u said Netflix but I gotta suggest it anyway 😭 if u have Apple TV+ you should 100% watch “the morning…
# Created at: 2019-12-03 02:49:57
# Clean tweet: ik u said Netflix but I gotta suggest it anyway if u have Apple TV you should 100 watch the morning
# ik u said Netflix but I gotta suggest it anyway if u have Apple TV you should 100 watch the morning
#  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# polarity: 0
# hashtags: []
# userId: 24247129, userName: princess lala, userScreenName: lexxaroze
# user follower count: 354, userFollowing: False
# user friends count: 516
# Lets begin to record! All the best :)
# latitude: None  logitude: None
# Tweet started
# Retweet status: False
# Original tweet: RT @TEOTFW: GUESS WHAT GUESS WHAT GUESS WHAT
#
# You can now change your @netflix profile icon...choose wisely! https://t.co/4Xa9elawCN
# Created at: 2019-12-03 02:49:57
# Clean tweet: GUESS WHAT GUESS WHAT GUESS WHAT You can now change your profile icon choose wisely
# GUESS WHAT GUESS WHAT GUESS WHAT You can now change your profile icon choose wisely
#  {'neg': 0.0, 'neu': 0.846, 'pos': 0.154, 'compound': 0.4753}
# polarity: 1
# hashtags: []
# userId: 1005422981131087872, userName: rolen, userScreenName: RolenPar
# user follower count: 247, userFollowing: False
# user friends count: 151
# Lets begin to record! All the best :)
# latitude: None  logitude: None
# Tweet started
# Retweet status: False
# Original tweet: Malcolm X is on Netflix. 🙌🏾
# Created at: 2019-12-03 02:49:58
# Clean tweet: Malcolm X is on Netflix
# Malcolm X is on Netflix-----------------
#  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# polarity: 0
# hashtags: []
# userId: 876065899, userName: KYM, userScreenName: WhoTheFuckIsKym
# user follower count: 1589, userFollowing: False
# user friends count: 3312
# Lets begin to record! All the best :)
# latitude: None  logitude: None
# Tweet started
# Retweet status: False
# Original tweet: Love and Basketball is on Netflix I REPEAT ITS ON NETFLIX
# Created at: 2019-12-03 02:49:58
# Clean tweet: Love and Basketball is on Netflix I REPEAT ITS ON NETFLIX
# Love and Basketball is on Netflix I REPEAT ITS ON NETFLIX
#  {'neg': 0.0, 'neu': 0.682, 'pos': 0.318, 'compound': 0.6369}
# polarity: 1
# hashtags: []
# userId: 4851727030, userName: KOD, userScreenName: lauratairi1
# user follower count: 1049, userFollowing: False
# user friends count: 464
# Lets begin to record! All the best :)
# latitude: None  logitude: None
# Tweet started
# Retweet status: False
# Original tweet: RT @bIairgillis: netflix🤝northwood
# waiting for the right &amp; most unexpected moment to announce that netflix now owns all the distribution ri…
# Created at: 2019-12-03 02:49:59
# Clean tweet: netflixnorthwood waiting for the right amp most unexpected moment to announce that netflix now owns all the distribution ri
# netflixnorthwood waiting for the right amp most unexpected moment to announce that netflix now owns all the distribution ri
#  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# polarity: 0
# hashtags: []
# userId: 1199086501641904128, userName: Kindred Spirit Ann 😏, userScreenName: annewithan_save
# user follower count: 152, userFollowing: False
# user friends count: 190
# Lets begin to record! All the best :)
# latitude: None  logitude: None
# Tweet started
# Retweet status: False
# Original tweet: RT @Niku30_: There he is! A first render of my fan art 3d model of #viren from #thedragonprince !! ⭐️ #thedragonprincefanart #thedragonprin…
# Created at: 2019-12-03 02:49:59
# Clean tweet: There he is A first render of my fan art 3d model of viren from thedragonprince thedragonprincefanart thedragonprin
# There he is A first render of my fan art 3d model of viren from thedragonprince thedragonprincefanart thedragonprin
#  {'neg': 0.0, 'neu': 0.863, 'pos': 0.137, 'compound': 0.4898}
# polarity: 1
# hashtags: ['viren', 'thedragonprince', 'thedragonprincefanart']
# userId: 1064896434, userName: Marcelo Espinoza, userScreenName: DestinationMarc
# user follower count: 824, userFollowing: False
# user friends count: 1050
# Lets begin to record! All the best :)
# latitude: None  logitude: None
# Tweet started
# Retweet status: False
# Original tweet: RT @ignacio_aries: what i want to watch:
#
# ⚪sunset
# ⚪netflix
# 🔘you while smiling
# Created at: 2019-12-03 02:49:59
# Clean tweet: what i want to watch sunset netflix you while smiling
# what i want to watch sunset netflix you while smiling
#  {'neg': 0.0, 'neu': 0.677, 'pos': 0.323, 'compound': 0.5106}
# polarity: 1
# hashtags: []
# userId: 1054662945613856770, userName: ᜑᜓᜈᜒᜌ᜔ᜎᜒᜆ᜔ᜑ᜔, userScreenName: hnylthcblg
# user follower count: 708, userFollowing: False
# user friends count: 1177
# Lets begin to record! All the best :)
# latitude: None  logitude: None
# Tweet started
# Retweet status: False
# Original tweet: Chief...
# Created at: 2019-12-03 02:50:00
# Clean tweet: Chief
# Chief-----------------------------------
#  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# polarity: 0
# hashtags: []
# userId: 4309307374, userName: Ze luis♟, userScreenName: JoseLuis2794
# user follower count: 75, userFollowing: False
# user friends count: 70
# Lets begin to record! All the best :)
# latitude: None  logitude: None
# Tweet started
# Retweet status: False
# Original tweet: @AndyColeTSN Titanic is on Netflix!
#
# I’ll be sure not to watch that garbage
# Created at: 2019-12-03 02:50:00
# Clean tweet: Titanic is on Netflix Ill be sure not to watch that garbage
# Titanic is on Netflix Ill be sure not to watch that garbage
#  {'neg': 0.0, 'neu': 0.822, 'pos': 0.178, 'compound': 0.3802}
# polarity: 1
# hashtags: []
# userId: 930266192278781953, userName: Kona Reeves Stan Account, userScreenName: Rye_Ethan14
# user follower count: 249, userFollowing: False
# user friends count: 1030
# Lets begin to record! All the best :)
# latitude: None  logitude: None
# Tweet started
# Retweet status: False
# Original tweet: blessed to be in a position to provide for my mother after she’s provided for me all these years (Netflix) https://t.co/PhJBIxdEhT
# Created at: 2019-12-03 02:50:02
# Clean tweet: blessed to be in a position to provide for my mother after shes provided for me all these years Netflix
# blessed to be in a position to provide for my mother after shes provided for me all these years Netflix
#  {'neg': 0.0, 'neu': 0.83, 'pos': 0.17, 'compound': 0.5994}
# polarity: 1
# hashtags: []
# userId: 211676751, userName: kendal, userScreenName: kendal_clouse
# user follower count: 658, userFollowing: False
# user friends count: 539
# Lets begin to record! All the best :)
# latitude: None  logitude: None
# Tweet started
# Retweet status: False
# Original tweet: RT @olrodlegacy: Best idea for football this year. https://t.co/6RVHBEGMs5
# Created at: 2019-12-03 02:50:03
# Clean tweet: Best idea for football this year
# Best idea for football this year--------
#  {'neg': 0.0, 'neu': 0.656, 'pos': 0.344, 'compound': 0.6369}
# polarity: 1
# hashtags: []
# userId: 159952866, userName: 5⭐Skills, userScreenName: Hariraja06
# user follower count: 370, userFollowing: False
# user friends count: 414
# Lets begin to record! All the best :)
# latitude: None  logitude: None
# Tweet started
# Retweet status: False
# Original tweet: RT @abelunsolved: netflix will reveal their end of the year statistics like they always do... if enough people rewatch anne with an e.... t…
# Created at: 2019-12-03 02:50:03
# Clean tweet: netflix will reveal their end of the year statistics like they always do if enough people rewatch anne with an e t
# netflix will reveal their end of the year statistics like they always do if enough people rewatch anne with an e t
#  {'neg': 0.0, 'neu': 0.902, 'pos': 0.098, 'compound': 0.3612}
# polarity: 1
# hashtags: []
# userId: 1199126025613000704, userName: For AnnE, userScreenName: SaveAnnEyousens
# user follower count: 94, userFollowing: False
# user friends count: 238
# Lets begin to record! All the best :)
# latitude: None  logitude: None
# Tweet started
# Retweet status: False
# Original tweet: these posts are a lot funnier when you the nigga she ignoring the texts for lmao
# Created at: 2019-12-03 02:50:04
# Clean tweet: these posts are a lot funnier when you the nigga she ignoring the texts for lmao
# these posts are a lot funnier when you the nigga she ignoring the texts for lmao
#  {'neg': 0.127, 'neu': 0.563, 'pos': 0.31, 'compound': 0.5994}
# polarity: 1
# hashtags: []
# userId: 1085717805310402561, userName: beastboy 🦖, userScreenName: samidioooo
# user follower count: 97, userFollowing: False
# user friends count: 257
# Lets begin to record! All the best :)
# latitude: None  logitude: None
# Tweet started
# Retweet status: False
# Original tweet: Just discovered season 2 of High Seas is on Netflix. I know what I’m doing tonight! https://t.co/91fZwfHd5l
# Created at: 2019-12-03 02:50:04
# Clean tweet: Just discovered season 2 of High Seas is on Netflix I know what Im doing tonight
# Just discovered season 2 of High Seas is on Netflix I know what Im doing tonight
#  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# polarity: 0
# hashtags: []
# userId: 326274975, userName: Jess 📚 Armstrong, userScreenName: JessL_Armstrong
# user follower count: 511, userFollowing: False
# user friends count: 442
# Lets begin to record! All the best :)
# latitude: None  logitude: None
# Tweet started
# Retweet status: False
# Original tweet: SALE! Today onlyyy
#
# SPOTIFY Premium Account PH
# ️ 3 months
#
#  New ACCOUNT
# — Php 50.00
#
# mop: paymaya | gcash | 7/11 |… https://t.co/JC6LJsf8wO
# Created at: 2019-12-03 02:50:04
# Clean tweet: SALE Today onlyy SPOTIFY Premium Account PH 3 months New ACCOUNT Php 50 00 mop paymaya gcash 7 11
# SALE Today onlyy SPOTIFY Premium Account PH 3 months New ACCOUNT Php 50 00 mop paymaya gcash 7 11
#  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# polarity: 0
# hashtags: []
# userId: 2765759904, userName: 💓, userScreenName: Aleeexxiiisssss
# user follower count: 312, userFollowing: False
# user friends count: 31
# Lets begin to record! All the best :)
# latitude: None  logitude: None
# Tweet started
# Retweet status: False
# Original tweet: RT @ignacio_aries: what i want to watch:
#
# ⚪sunset
# ⚪netflix
# 🔘you while smiling
# Created at: 2019-12-03 02:50:04
# Clean tweet: what i want to watch sunset netflix you while smiling
# what i want to watch sunset netflix you while smiling
#  {'neg': 0.0, 'neu': 0.677, 'pos': 0.323, 'compound': 0.5106}
# polarity: 1
# hashtags: []
# userId: 1063771121227460608, userName: rio •, userScreenName: rioviray_
# user follower count: 262, userFollowing: False
# user friends count: 190
# Lets begin to record! All the best :)
# latitude: None  logitude: None
# Tweet started
# Retweet status: False
# Original tweet: RT @scrawfish: Netflix just added THE LONG KISS GOODNIGHT! It’s Shane Black, so it’s a moral imperative to either finally see it or rewatch…
# Created at: 2019-12-03 02:50:05
# Clean tweet: Netflix just added THE LONG KISS GOODNIGHT Its Shane Black so its a moral imperative to either finally see it or rewatch
# Netflix just added THE LONG KISS GOODNIGHT Its Shane Black so its a moral imperative to either finally see it or rewatch
#  {'neg': 0.0, 'neu': 0.852, 'pos': 0.148, 'compound': 0.5893}
# polarity: 1
# hashtags: []
# userId: 34188932, userName: Steve R. Seigh, userScreenName: dead_anchoress
# user follower count: 2022, userFollowing: False
# user friends count: 1321
# Lets begin to record! All the best :)
# latitude: None  logitude: None
# Tweet started
# Retweet status: False
# Original tweet: RT @katiebevo18: NO WAY FIVE FEET APART IS COMING ONTO NETFLIX SOON 🥺🥺🥺
# I haven’t see. It in so long omg!!! I’m ready to cry again 🥺❤️
# @co…
# Created at: 2019-12-03 02:50:05
# Clean tweet: NO WAY FIVE FEET APART IS COMING ONTO NETFLIX SOON I havent see It in so long omg Im ready to cry again
# NO WAY FIVE FEET APART IS COMING ONTO NETFLIX SOON I havent see It in so long omg Im ready to cry again
#  {'neg': 0.207, 'neu': 0.718, 'pos': 0.075, 'compound': -0.6607}
# polarity: -1
# hashtags: []
# userId: 989559801586896897, userName: eh 🥰, userScreenName: sincerelyher
# user follower count: 41, userFollowing: False
# user friends count: 203
# Lets begin to record! All the best :)
# latitude: None  logitude: None
# Tweet started
# Retweet status: False
# Original tweet: @fIowerbody same with all of those shitty netflix series honestly djdnffn
# Created at: 2019-12-03 02:50:05
# Clean tweet: same with all of those shitty netflix series honestly djdnffn
# same with all of those shitty netflix series honestly djdnffn
#  {'neg': 0.231, 'neu': 0.577, 'pos': 0.192, 'compound': -0.1531}
# polarity: -1
# hashtags: []
# userId: 1161903234656735232, userName: summer, userScreenName: confusedbich
# user follower count: 136, userFollowing: False
# user friends count: 101
# Lets begin to record! All the best :)
# latitude: None  logitude: None
# Tweet started
# Retweet status: False
# Original tweet: RT @RHXKA: if you guys haven’t watched After on Netflix please do so I’ve been crying ever since 😩
# Created at: 2019-12-03 02:50:06
# Clean tweet: if you guys havent watched After on Netflix please do so Ive been crying ever since
# if you guys havent watched After on Netflix please do so Ive been crying ever since
#  {'neg': 0.155, 'neu': 0.739, 'pos': 0.106, 'compound': -0.2648}
# polarity: -1
# hashtags: []
# userId: 3332239917, userName: 👼🏻, userScreenName: dg0ldix
# user follower count: 491, userFollowing: False
# user friends count: 186
# Lets begin to record! All the best :)
# latitude: None  logitude: None
# Tweet started
# Retweet status: False
# Original tweet: Once Netflix gets icarly ... I’m disappearing for very long time Lmfaooo
# Created at: 2019-12-03 02:50:06
# Clean tweet: Once Netflix gets icarly Im disappearing for very long time Lmfaoo
# Once Netflix gets icarly Im disappearing for very long time Lmfaoo
#  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# polarity: 0
# hashtags: []
# userId: 2948064539, userName: Tristan Thompson, userScreenName: gloBaahL
# user follower count: 726, userFollowing: False
# user friends count: 649
# Lets begin to record! All the best :)
# latitude: None  logitude: None
# Tweet started
# Retweet status: False
# Original tweet: we're not giving up @heretv @HereMediaInc @AmazonVideo @netflix @hulu @Showtime @showcasedotca #WeWantEyewitnessSeason2
# Created at: 2019-12-03 02:50:07
# Clean tweet: we re not giving up WeWantEyewitnessSeason2
# we re not giving up WeWantEyewitnessSeason2
#  {'neg': 0.156, 'neu': 0.844, 'pos': 0.0, 'compound': -0.2584}
# polarity: -1
# hashtags: ['WeWantEyewitnessSeason2']
# userId: 860817801199710208, userName: save eyewitness, userScreenName: save_eyewitness
# user follower count: 37, userFollowing: False
# user friends count: 26
# Lets begin to record! All the best :)
# latitude: None  logitude: None
# Tweet started
# Retweet status: False
# Original tweet: RT @exokiss88: EXO performed Obsession at the Netflix 6 Underground Green Carpet
#
# Our boys are amazing 👍🏻💕 but but but... the camera ㅠㅠㅠㅠ…
# Created at: 2019-12-03 02:50:08
# Clean tweet: EXO performed Obsession at the Netflix 6 Underground Green Carpet Our boys are amazing but but but the camera
# EXO performed Obsession at the Netflix 6 Underground Green Carpet Our boys are amazing but but but the camera
#  {'neg': 0.071, 'neu': 0.83, 'pos': 0.1, 'compound': 0.1779}
# polarity: 1
# hashtags: []
# userId: 2362569462, userName: 🥀, userScreenName: kleirdelune
# user follower count: 191, userFollowing: False
# user friends count: 175
# Lets begin to record! All the best :)
# latitude: None  logitude: None
# Tweet started
# Retweet status: False
# Original tweet: RT @myannewane: y'all hear him say "Anne" at 0.04? yeah - let that motivate you.
# @BBCOne @STARZ @ITV @PopTV
# #SAVE_AWAE #RENEWANNEWITHANE…
# Created at: 2019-12-03 02:50:07
# Clean tweet: y all hear him say Anne at 0 04 yeah let that motivate you SAVE AWAE RENEWANNEWITHANE
# y all hear him say Anne at 0 04 yeah let that motivate you SAVE AWAE RENEWANNEWITHANE
#  {'neg': 0.0, 'neu': 0.789, 'pos': 0.211, 'compound': 0.5859}
# polarity: 1
# hashtags: ['SAVE_AWAE', 'RENEWANNEWITHANE']
# userId: 1200241330145902597, userName: meghan, userScreenName: mellowmegg
# user follower count: 105, userFollowing: False
# user friends count: 140
# Lets begin to record! All the best :)
# latitude: None  logitude: None
# Tweet started
# Retweet status: False
# Original tweet: are you okay
# Created at: 2019-12-03 02:50:08
# Clean tweet: are you okay
# are you okay----------------------------
#  {'neg': 0.0, 'neu': 0.513, 'pos': 0.487, 'compound': 0.2263}
# polarity: 1
# hashtags: []
# userId: 254697381, userName: logan, userScreenName: laogn
# user follower count: 3248, userFollowing: False
# user friends count: 525
# Lets begin to record! All the best :)
# latitude: None  logitude: None
# Tweet started
# Retweet status: False
# Original tweet: Fa loco ni Netflix me anda hoy
# Created at: 2019-12-03 02:50:08
# Clean tweet: Fa loco ni Netflix me anda hoy
# Fa loco ni Netflix me anda hoy----------
#  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# polarity: 0
# hashtags: []
# userId: 158937197, userName: Луана, userScreenName: lu_marquezg
# user follower count: 1843, userFollowing: False
# user friends count: 2292
# Lets begin to record! All the best :)
# latitude: None  logitude: None
# Tweet started
# Retweet status: False
# Original tweet: RT @dayumiumz: SELLING
# 👉spotify
# 2mos P60
# 3mos P80
# renew 3mos P110
# 8mos 250 new / 280 renew
#
# 👉netflix
# 1month
# solo 190pesos
# shared 90pesos…
# Created at: 2019-12-03 02:50:10
# Clean tweet: SELLING spotify 2mos P60 3mos P80 renew 3mos P110 8mos 250 new 280 renew netflix 1month solo 190pesos shared 90pesos
# SELLING spotify 2mos P60 3mos P80 renew 3mos P110 8mos 250 new 280 renew netflix 1month solo 190pesos shared 90pesos
#  {'neg': 0.0, 'neu': 0.897, 'pos': 0.103, 'compound': 0.34}
# polarity: 1
# hashtags: []
# userId: 1201339781415784449, userName: RILAKKUMA, userScreenName: iamrilakkuma__
# user follower count: 150, userFollowing: False
# user friends count: 437
# Lets begin to record! All the best :)
# latitude: None  logitude: None
# Tweet started
# Retweet status: False
# Original tweet: RT @IsraelUSAforevr: RETWEET if you will NOT be watching Barack and Michelle Obama’s Netflix series!
# Created at: 2019-12-03 02:50:10
# Clean tweet: RETWEET if you will NOT be watching Barack and Michelle Obamas Netflix series
# RETWEET if you will NOT be watching Barack and Michelle Obamas Netflix series
#  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# polarity: 0
# hashtags: []
# userId: 892065560527331328, userName: Satellite Mike, userScreenName: michael_stohler
# user follower count: 437, userFollowing: False
# user friends count: 703
# Lets begin to record! All the best :)
# latitude: None  logitude: None
# Tweet started
# Retweet status: False
# Original tweet: RT @Rockprincess818: Well when CBS, NBC, ABC, CNN, MSNBC, HBO, Netflix and Bloomberg News are actively working on the behalf of Democrats,…
# Created at: 2019-12-03 02:50:10
# Clean tweet: Well when CBS NBC ABC CNN MSNBC HBO Netflix and Bloomberg News are actively working on the behalf of Democrats
# Well when CBS NBC ABC CNN MSNBC HBO Netflix and Bloomberg News are actively working on the behalf of Democrats
#  {'neg': 0.0, 'neu': 0.82, 'pos': 0.18, 'compound': 0.5267}
# polarity: 1
# hashtags: []
# userId: 3416691374, userName: Lake Deplorable 🇺🇸🇺🇸, userScreenName: Lake4963
# user follower count: 4196, userFollowing: False
# user friends count: 4674
# Lets begin to record! All the best :)
# latitude: None  logitude: None
# Tweet started
# Retweet status: False
# Original tweet: RT @_cami_4: righttt #renewannewithane https://t.co/rHyKLnAl69
# Created at: 2019-12-03 02:50:10
# Clean tweet: rightt renewannewithane
# rightt renewannewithane-----------------
#  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# polarity: 0
# hashtags: ['renewannewithane']
# userId: 834892575106478080, userName: Yessi, userScreenName: Yessi99140504
# user follower count: 53, userFollowing: False
# user friends count: 32
# Lets begin to record! All the best :)
# latitude: None  logitude: None
# Tweet started
# Retweet status: False
# Original tweet: Malcolm X is streaming on Netflix. I’m going to be mad at the YTs for at least the rest of the week.
# Created at: 2019-12-03 02:50:11
# Clean tweet: Malcolm X is streaming on Netflix Im going to be mad at the YTs for at least the rest of the week
# Malcolm X is streaming on Netflix Im going to be mad at the YTs for at least the rest of the week
#  {'neg': 0.138, 'neu': 0.862, 'pos': 0.0, 'compound': -0.4939}
# polarity: -1
# hashtags: []
# userId: 65784277, userName: She Who Must Not Be Named, userScreenName: Viva_La_Vee
# user follower count: 583, userFollowing: False
# user friends count: 573
# Lets begin to record! All the best :)
# latitude: None  logitude: None
# Tweet started
# Retweet status: False
# Original tweet: RT @ignacio_aries: what i want to watch:
#
# ⚪sunset
# ⚪netflix
# 🔘you while smiling
# Created at: 2019-12-03 02:50:11
# Clean tweet: what i want to watch sunset netflix you while smiling
# what i want to watch sunset netflix you while smiling
#  {'neg': 0.0, 'neu': 0.677, 'pos': 0.323, 'compound': 0.5106}
# polarity: 1
# hashtags: []
# userId: 1053162517076238336, userName: mei-meiya, userScreenName: mayaauseri
# user follower count: 44, userFollowing: False
# user friends count: 80
# Lets begin to record! All the best :)
# latitude: None  logitude: None
# Tweet started
# Retweet status: False
# Original tweet: RT @ignacio_aries: what i want to watch:
#
# ⚪sunset
# ⚪netflix
# 🔘you while smiling
# Created at: 2019-12-03 02:50:11
# Clean tweet: what i want to watch sunset netflix you while smiling
# what i want to watch sunset netflix you while smiling
#  {'neg': 0.0, 'neu': 0.677, 'pos': 0.323, 'compound': 0.5106}
# polarity: 1
# hashtags: []
# userId: 2688977767, userName: remartjay, userScreenName: rmrtjy
# user follower count: 487, userFollowing: False
# user friends count: 407
# Lets begin to record! All the best :)
# latitude: None  logitude: None
# Tweet started
# Retweet status: False
# Original tweet: @oluwa_funto I heard Netflix helps
# Created at: 2019-12-03 02:50:11
# Clean tweet: funto I heard Netflix helps
# funto I heard Netflix helps-------------
#  {'neg': 0.0, 'neu': 0.536, 'pos': 0.464, 'compound': 0.3818}
# polarity: 1
# hashtags: []
# userId: 1327609776, userName: Tanaka, userScreenName: TanakaZee
# user follower count: 155, userFollowing: False
# user friends count: 146
# Lets begin to record! All the best :)
# latitude: None  logitude: None
# Tweet started
# Retweet status: False
# Original tweet: CHANDLER OBVIO
# Created at: 2019-12-03 02:50:12
# Clean tweet: CHANDLER OBVIO
# CHANDLER OBVIO--------------------------
#  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# polarity: 0
# hashtags: []
# userId: 170897951, userName: Lᴜᴄɪᴇ́ʀɴᴀɢᴀ💚 !, userScreenName: EmaaLucero
# user follower count: 413, userFollowing: False
# user friends count: 354
# Lets begin to record! All the best :)
# latitude: None  logitude: None
# Tweet started
# Retweet status: False
# Original tweet: RT @GlossnPumps803: Still haven’t seen this and don’t plan on it https://t.co/t28vp4kWGS
# Created at: 2019-12-03 02:50:13
# Clean tweet: Still havent seen this and dont plan on it
# Still havent seen this and dont plan on it
#  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# polarity: 0
# hashtags: []
# userId: 155901395, userName: Eastside Johnny🏁💙🙏🏾, userScreenName: Just_JayyTee
# user follower count: 2595, userFollowing: False
# user friends count: 1850
# Lets begin to record! All the best :)
# latitude: None  logitude: None
# Tweet started
# Retweet status: False
# Original tweet: RT @goodbeanalt: shes laying in his king sized bed, watching Netflix. she sees your text. she ignores it and puts her phone on do not distu…
# Created at: 2019-12-03 02:50:13
# Clean tweet: shes laying in his king sized bed watching Netflix she sees your text she ignores it and puts her phone on do not distu
# shes laying in his king sized bed watching Netflix she sees your text she ignores it and puts her phone on do not distu
#  {'neg': 0.077, 'neu': 0.923, 'pos': 0.0, 'compound': -0.2732}
# polarity: -1
# hashtags: []
# userId: 42306910, userName: ItsAlexBih, userScreenName: ItsAlexBih
# user follower count: 2409, userFollowing: False
# user friends count: 551
# Lets begin to record! All the best :)
# latitude: None  logitude: None
# Tweet started
# Retweet status: False
# Original tweet: RT @jowaaash: PSA: WATCH DEAD KIDS. IT'S ON NETFLIX. JESUS FUCKING CHRIST IT'S GONNA BE THE BEST THING YOU'LL EVER WATCH IN MONTHS. AND MIG…
# Created at: 2019-12-03 02:50:14
# Clean tweet: PSA WATCH DEAD KIDS IT S ON NETFLIX JESUS FUCKING CHRIST IT S GONNA BE THE BEST THING YOU LL EVER WATCH IN MONTHS AND MIG
# PSA WATCH DEAD KIDS IT S ON NETFLIX JESUS FUCKING CHRIST IT S GONNA BE THE BEST THING YOU LL EVER WATCH IN MONTHS AND MIG
#  {'neg': 0.153, 'neu': 0.698, 'pos': 0.15, 'compound': -0.0258}
# polarity: 0
# hashtags: []
# userId: 2725536972, userName: t r e x i e, userScreenName: trexieannlargo
# user follower count: 718, userFollowing: False
# user friends count: 1086
# Lets begin to record! All the best :)
# latitude: None  logitude: None
# Tweet started
# Retweet status: False
# Original tweet: RT @MatthewACherry: Give Betty her things! https://t.co/3UJ4ZmdoZq
# Created at: 2019-12-03 02:50:14
# Clean tweet: Give Betty her things
# Give Betty her things-------------------
#  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# polarity: 0
# hashtags: []
# userId: 124386779, userName: Maggie Wrobel, userScreenName: maggiewrobel
# user follower count: 2904, userFollowing: False
# user friends count: 1573
# Lets begin to record! All the best :)
# latitude: None  logitude: None
# Tweet started
# Retweet status: False
# Original tweet: RT @rendirendiPrada: They really took Love Jones off of Netflix the one day I needed it the most 😒 I fucking hate it here
# Created at: 2019-12-03 02:50:14
# Clean tweet: They really took Love Jones off of Netflix the one day I needed it the most I fucking hate it here
# They really took Love Jones off of Netflix the one day I needed it the most I fucking hate it here
#  {'neg': 0.154, 'neu': 0.685, 'pos': 0.161, 'compound': 0.0534}
# polarity: 1
# hashtags: []
# userId: 262971394, userName: GIFTOFGOD, userScreenName: iamnateIV
# user follower count: 1682, userFollowing: False
# user friends count: 1142
# Lets begin to record! All the best :)
# latitude: None  logitude: None
# Tweet started
# Retweet status: False
# Original tweet: I don’t watch Netflix shows without subtitles
# Created at: 2019-12-03 02:50:14
# Clean tweet: I dont watch Netflix shows without subtitles
# I dont watch Netflix shows without subtitles
#  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# polarity: 0
# hashtags: []
# userId: 100140410, userName: Ken St. Louis, userScreenName: kenncashO3
# user follower count: 1053, userFollowing: False
# user friends count: 971
# Lets begin to record! All the best :)
# latitude: None  logitude: None
# Tweet started
# Retweet status: False
# Original tweet: RT @Kpop_Herald: Photo flash: @weareoneEXO on the green carpet event for @netflix's upcoming flick "6 Underground" in Seoul. https://t.co/a…
# Created at: 2019-12-03 02:50:15
# Clean tweet: Photo flash on the green carpet event for s upcoming flick 6 Underground in Seoul
# Photo flash on the green carpet event for s upcoming flick 6 Underground in Seoul
#  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# polarity: 0
# hashtags: []
# userId: 1153511742179119104, userName: All🐾, userScreenName: 26lkajoo
# user follower count: 47, userFollowing: False
# user friends count: 174
# Lets begin to record! All the best :)
# latitude: None  logitude: None
# Tweet started
# Retweet status: False
# Original tweet: RT @InqEnt: #ryanreynolds #AdriaArjona #MelanieLaurent trying to “shake their groove thing” after #EXO’s song &amp; dance number @InqEnt @Upper…
# Created at: 2019-12-03 02:50:15
# Clean tweet: ryanreynolds AdriaArjona MelanieLaurent trying to shake their groove thing after EXOs song amp dance number
# ryanreynolds AdriaArjona MelanieLaurent trying to shake their groove thing after EXOs song amp dance number
#  {'neg': 0.0, 'neu': 0.933, 'pos': 0.067, 'compound': 0.0772}
# polarity: 1
# hashtags: ['ryanreynolds', 'AdriaArjona', 'MelanieLaurent', 'EXO']
# userId: 866795739246153728, userName: ᴏʙꜱᴇꜱꜱɪᴏɴ༄ ᶜᵃˢᵉ ⁻ ⁰⁴, userScreenName: Stace_Privat
# user follower count: 288, userFollowing: False
# user friends count: 276
# Lets begin to record! All the best :)
# latitude: None  logitude: None
# Tweet started
# Retweet status: False
# Original tweet: WOW BEN LOOKS SO GOOD IN HIS 1 SECOND APPEARANCE
# https://t.co/OKrENQKiDi
# Created at: 2019-12-03 02:50:15
# Clean tweet: WOW BEN LOOKS SO GOOD IN HIS 1 SECOND APPEARANCE
# WOW BEN LOOKS SO GOOD IN HIS 1 SECOND APPEARANCE
#  {'neg': 0.0, 'neu': 0.465, 'pos': 0.535, 'compound': 0.8805}
# polarity: 1
# hashtags: []
# userId: 3259425913, userName: diana 🍒 FINE LINE AND 6U ON MY BDAY 11, userScreenName: cherryxspidey
# user follower count: 2180, userFollowing: False
# user friends count: 1590
# Lets begin to record! All the best :)
# latitude: None  logitude: None
# Tweet started
# Retweet status: False
# Original tweet: RT @intokai: GIF #카이 #KAI  •191202 EXO
# NETFLIX 6UNDERGROUND World Premiere Green Carpet #6UndergroundxEXO
#
# ↳ https://t.co/iieqK6tI4Q http…
# Created at: 2019-12-03 02:50:16
# Clean tweet: GIF KAI 191202 EXO NETFLIX 6UNDERGROUND World Premiere Green Carpet 6UndergroundxEXO http
# GIF KAI 191202 EXO NETFLIX 6UNDERGROUND World Premiere Green Carpet 6UndergroundxEXO http
#  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# polarity: 0
# hashtags: ['카이', 'KAI', '6UndergroundxEXO']
# userId: 759990447640940546, userName: Phương Thảo, userScreenName: thbae0205
# user follower count: 51, userFollowing: False
# user friends count: 348
# Lets begin to record! All the best :)
# latitude: None  logitude: None
# Tweet started
# Retweet status: False
# Original tweet: RT @InqEnt: #ryanreynolds #AdriaArjona #MelanieLaurent trying to “shake their groove thing” after #EXO’s song &amp; dance number @InqEnt @Upper…
# Created at: 2019-12-03 02:50:16
# Clean tweet: ryanreynolds AdriaArjona MelanieLaurent trying to shake their groove thing after EXOs song amp dance number
# ryanreynolds AdriaArjona MelanieLaurent trying to shake their groove thing after EXOs song amp dance number
#  {'neg': 0.0, 'neu': 0.933, 'pos': 0.067, 'compound': 0.0772}
# polarity: 1
# hashtags: ['ryanreynolds', 'AdriaArjona', 'MelanieLaurent', 'EXO']
# userId: 1196700475761889280, userName: Loeychan27, userScreenName: Luv12348
# user follower count: 0, userFollowing: False
# user friends count: 36
# Lets begin to record! All the best :)
# ...
# polarity: 0
# hashtags: ['EXO', '6Underground']
# userId: 791333279999729664, userName: happyvirusKK, userScreenName: exolkkts1998
# user follower count: 76, userFollowing: False
# user friends count: 373
# Lets begin to record! All the best :)
# latitude: None  logitude: None
# Tweet started
# Retweet status: False
# Original tweet: RT @talkSPORT: “I think the Premier League should become their own broadcaster.” 🎥
#
# “People are churning off Sky and BT, they don’t want to…
# Created at: 2019-12-03 03:45:38
# Clean tweet: I think the Premier League should become their own broadcaster People are churning off Sky and BT they dont want to
# I think the Premier League should become their own broadcaster People are churning off Sky and BT they dont want to
#  {'neg': 0.0, 'neu': 0.944, 'pos': 0.056, 'compound': 0.0772}
# polarity: 1
# hashtags: []
# userId: 888658933828792324, userName: alCOLEholic, userScreenName: allankmuchai
# user follower count: 119, userFollowing: False
# user friends count: 188
# Lets begin to record! All the best :)
# latitude: None  logitude: None
# Tweet started
# Retweet status: False
# Original tweet: RT @theseoulstory: 📸 EXO at the green carpet event of Netflix movie '6 Underground' today 💕 @weareoneEXO https://t.co/7RdUeaTBM9
# Created at: 2019-12-03 03:45:38
# Clean tweet: EXO at the green carpet event of Netflix movie 6 Underground today
# EXO at the green carpet event of Netflix movie 6 Underground today
#  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# polarity: 0
# hashtags: []
# userId: 1162096782693687296, userName: Mi Conejito se llama rabito, userScreenName: deysi_eneque
# user follower count: 65, userFollowing: False
# user friends count: 319
# Lets begin to record! All the best :)
# latitude: None  logitude: None
# Tweet started
# Retweet status: False
# Original tweet: RT @AnnaJKlassen: Love seeing my friend @StevenEdeSouza talk about writing DIE HARD on @netflix' MOVIES THAT MADE US (in his/my favorite ea…
# Created at: 2019-12-03 03:45:38
# Clean tweet: Love seeing my friend talk about writing DIE HARD on MOVIES THAT MADE US in his my favorite ea
# Love seeing my friend talk about writing DIE HARD on MOVIES THAT MADE US in his my favorite ea
#  {'neg': 0.198, 'neu': 0.498, 'pos': 0.304, 'compound': 0.5624}
# polarity: 1
# hashtags: []
# userId: 738632756976984065, userName: Christian Elder, userScreenName: Xian_Elder
# user follower count: 851, userFollowing: False
# user friends count: 1055
# Lets begin to record! All the best :)
# latitude: None  logitude: None
# Tweet started
# Retweet status: False
# Original tweet: RT @bgttibz: Nobody:
#
# Netflix: https://t.co/mQt4Y1W4fn
# Created at: 2019-12-03 03:45:39
# Clean tweet: Nobody Netflix
# Nobody Netflix--------------------------
#  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# polarity: 0
# hashtags: []
# userId: 3441403215, userName: kelly, userScreenName: kellynoriegaa
# user follower count: 110, userFollowing: False
# user friends count: 102
# Lets begin to record! All the best :)
# latitude: None  logitude: None
# Tweet started
# Retweet status: False
# Original tweet: I wrote this.
# Created at: 2019-12-03 03:45:40
# Clean tweet: I wrote this
# I wrote this----------------------------
#  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# polarity: 0
# hashtags: []
# userId: 67406548, userName: James Patrick, userScreenName: 007hertzrumble
# user follower count: 3687, userFollowing: False
# user friends count: 2659
# Lets begin to record! All the best :)
# latitude: None  logitude: None
# Tweet started
# Retweet status: False
# Original tweet: kevin wendell crumb
# Created at: 2019-12-03 03:45:40
# Clean tweet: kevin wendell crumb
# kevin wendell crumb---------------------
#  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# polarity: 0
# hashtags: []
# userId: 744992207862697986, userName: yamila, userScreenName: yamibiebersb
# user follower count: 1722, userFollowing: False
# user friends count: 245
# Lets begin to record! All the best :)
# latitude: None  logitude: None
# Tweet started
# Retweet status: False
# Original tweet: RT @BBW_BFF: PSA: The Long Kiss Goodnight, one of my favorite movies ever, is on Netflix now. essential viewing during the holidays and any…
# Created at: 2019-12-03 03:45:40
# Clean tweet: PSA The Long Kiss Goodnight one of my favorite movies ever is on Netflix now essential viewing during the holidays and any
# PSA The Long Kiss Goodnight one of my favorite movies ever is on Netflix now essential viewing during the holidays and any
#  {'neg': 0.0, 'neu': 0.714, 'pos': 0.286, 'compound': 0.8126}
# polarity: 1
# hashtags: []
# userId: 4496441607, userName: Mark Diaz, userScreenName: coolmarkd
# user follower count: 176, userFollowing: False
# user friends count: 2040
# Lets begin to record! All the best :)
# latitude: None  logitude: None
# Tweet started
# Retweet status: False
# Original tweet: Fredo - Netflix &amp; Chill https://t.co/Cy1ctuYpzN
# Created at: 2019-12-03 03:45:41
# Clean tweet: Fredo Netflix amp Chill
# Fredo Netflix amp Chill-----------------
#  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# polarity: 0
# hashtags: []
# userId: 819577546807373826, userName: Power Radio #NowPlaying, userScreenName: nowplayingpower
# user follower count: 422, userFollowing: False
# user friends count: 39
# Lets begin to record! All the best :)
# latitude: None  logitude: None
# Tweet started
# Retweet status: False
# Original tweet: @HerbertHistory @netflix It is excellent and I really look forward to reading everyone's thoughts on it.
# Created at: 2019-12-03 03:45:41
# Clean tweet: It is excellent and I really look forward to reading everyone s thoughts on it
# It is excellent and I really look forward to reading everyone s thoughts on it
#  {'neg': 0.0, 'neu': 0.791, 'pos': 0.209, 'compound': 0.5719}
# polarity: 1
# hashtags: []
# userId: 763281824, userName: Heather Scheurer, userScreenName: heatherscheurer
# user follower count: 229, userFollowing: False
# user friends count: 348
# Lets begin to record! All the best :)
# latitude: None  logitude: None
# Tweet started
# Retweet status: False
# Original tweet: RT @FreeBSDHelp: FreeBSD's TCP stack just added stats(3) framework support, "making it possible to retrieve per-connection statistical info…
# Created at: 2019-12-03 03:45:42
# Clean tweet: FreeBSD s TCP stack just added stats 3 framework support making it possible to retrieve per connection statistical info
# FreeBSD s TCP stack just added stats 3 framework support making it possible to retrieve per connection statistical info
#  {'neg': 0.0, 'neu': 0.863, 'pos': 0.137, 'compound': 0.4019}
# polarity: 1
# hashtags: []
# userId: 213387406, userName: Andrey Fesenko, userScreenName: f0andrey
# user follower count: 344, userFollowing: False
# user friends count: 192
# Lets begin to record! All the best :)
# latitude: None  logitude: None
# Tweet started
# Retweet status: False
# Original tweet: RT @britmarling: chills @themisstoto chills https://t.co/EW59Uahw7o
# Created at: 2019-12-03 03:45:42
# Clean tweet: chills chills
# chills chills---------------------------
#  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# polarity: 0
# hashtags: []
# userId: 1201693779268235264, userName: mizu, userScreenName: mizu85378235
# user follower count: 0, userFollowing: False
# user friends count: 3
# Lets begin to record! All the best :)
# latitude: None  logitude: None
# Tweet started
# Retweet status: False
# Original tweet: It's been 5 fucking years since I watched hxh and Netflix still doesn't have all the episodes....lol
# Created at: 2019-12-03 03:45:43
# Clean tweet: It s been 5 fucking years since I watched hxh and Netflix still doesn t have all the episodes lol
# It s been 5 fucking years since I watched hxh and Netflix still doesn t have all the episodes lol
#  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# polarity: 0
# hashtags: []
# userId: 1073453501349539840, userName: Ignant🎃, userScreenName: __ignant
# user follower count: 697, userFollowing: False
# user friends count: 329
# Lets begin to record! All the best :)
# latitude: None  logitude: None
# Tweet started
# Retweet status: False
# Original tweet: I gotta say, Joe Pesci was pretty damn good in #TheIrishman
#
# Pacino, De Niro awesome.  Can you give an Oscar Nomin… https://t.co/7iSWaCAE39
# Created at: 2019-12-03 03:45:43
# Clean tweet: I gotta say Joe Pesci was pretty damn good in TheIrishman Pacino De Niro awesome Can you give an Oscar Nomin
# I gotta say Joe Pesci was pretty damn good in TheIrishman Pacino De Niro awesome Can you give an Oscar Nomin
#  {'neg': 0.09, 'neu': 0.569, 'pos': 0.341, 'compound': 0.8176}
# polarity: 1
# hashtags: ['TheIrishman']
# userId: 2704681687, userName: Ethical Skeptic ☀, userScreenName: EthicalSkeptic
# user follower count: 1631, userFollowing: False
# user friends count: 958
# Lets begin to record! All the best :)
# latitude: None  logitude: None
# Tweet started
# Retweet status: False
# Original tweet: RT @shariq911: Companies made their first $1 Billion.
#
# @binance:2 years 👏
# @Google:5 years
# @facebook:6 years
# @Spotify:8 years
# @Dropbox:10 y…
# Created at: 2019-12-03 03:45:43
# Clean tweet: Companies made their first 1 Billion 2 years 5 years 6 years 8 years 10 y
# Companies made their first 1 Billion 2 years 5 years 6 years 8 years 10 y
#  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# polarity: 0
# hashtags: []
# userId: 992171474462167043, userName: Buck Shot, userScreenName: Buck_Shot88
# user follower count: 92, userFollowing: False
# user friends count: 397
# Lets begin to record! All the best :)
# latitude: None  logitude: None
# ---------------------------------------------------------------------------
# WantReadError                             Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/urllib3/contrib/pyopenssl.py in recv_into(self, *args, **kwargs)
#     296         try:
# --> 297             return self.connection.recv_into(*args, **kwargs)
#     298         except OpenSSL.SSL.SysCallError as e:
#
# ~/anaconda3/lib/python3.7/site-packages/OpenSSL/SSL.py in recv_into(self, buffer, nbytes, flags)
#    1821             result = _lib.SSL_read(self._ssl, buf, nbytes)
# -> 1822         self._raise_ssl_error(self._ssl, result)
#    1823
#
# ~/anaconda3/lib/python3.7/site-packages/OpenSSL/SSL.py in _raise_ssl_error(self, ssl, result)
#    1621         if error == _lib.SSL_ERROR_WANT_READ:
# -> 1622             raise WantReadError()
#    1623         elif error == _lib.SSL_ERROR_WANT_WRITE:
#
# WantReadError:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-21077b3bcca8> in <module>
#       1 myStreamListener = MyStreamListener()
#       2 myStream = tweepy.Stream(auth = api.auth, listener = myStreamListener)
# ----> 3 myStream.filter(languages=["en"], track = twitter_settings.TRACK_WORDS)
#       4 # Close the MySQL connection as it finished
#       5 # However, this won't be reached as the stream listener won't stop automatically
#
# ~/anaconda3/lib/python3.7/site-packages/tweepy/streaming.py in filter(self, follow, track, is_async, locations, stall_warnings, languages, encoding, filter_level)
#     472             self.body['filter_level'] = filter_level.encode(encoding)
#     473         self.session.params = {'delimited': 'length'}
# --> 474         self._start(is_async)
#     475
#     476     def sitestream(self, follow, stall_warnings=False,
#
# ~/anaconda3/lib/python3.7/site-packages/tweepy/streaming.py in _start(self, is_async)
#     387             self._thread.start()
#     388         else:
# --> 389             self._run()
#     390
#     391     def on_closed(self, resp):
#
# ~/anaconda3/lib/python3.7/site-packages/tweepy/streaming.py in _run(self)
#     287                     self.snooze_time = self.snooze_time_step
#     288                     self.listener.on_connect()
# --> 289                     self._read_loop(resp)
#     290             except (Timeout, ssl.SSLError) as exc:
#     291                 # This is still necessary, as a SSLError can actually be
#
# ~/anaconda3/lib/python3.7/site-packages/tweepy/streaming.py in _read_loop(self, resp)
#     337             length = 0
#     338             while not resp.raw.closed:
# --> 339                 line = buf.read_line()
#     340                 stripped_line = line.strip() if line else line # line is sometimes None so we need to check here
#     341                 if not stripped_line:
#
# ~/anaconda3/lib/python3.7/site-packages/tweepy/streaming.py in read_line(self, sep)
#     198             else:
#     199                 start = len(self._buffer)
# --> 200             self._buffer += self._stream.read(self._chunk_size)
#     201         return six.b('')
#     202
#
# ~/anaconda3/lib/python3.7/site-packages/urllib3/response.py in read(self, amt, decode_content, cache_content)
#     440             else:
#     441                 cache_content = False
# --> 442                 data = self._fp.read(amt)
#     443                 if amt != 0 and not data:  # Platform-specific: Buggy versions of Python.
#     444                     # Close the connection when no data is returned
#
# ~/anaconda3/lib/python3.7/http/client.py in read(self, amt)
#     445             # Amount is given, implement using readinto
#     446             b = bytearray(amt)
# --> 447             n = self.readinto(b)
#     448             return memoryview(b)[:n].tobytes()
#     449         else:
#
# ~/anaconda3/lib/python3.7/http/client.py in readinto(self, b)
#     479
#     480         if self.chunked:
# --> 481             return self._readinto_chunked(b)
#     482
#     483         if self.length is not None:
#
# ~/anaconda3/lib/python3.7/http/client.py in _readinto_chunked(self, b)
#     574         try:
#     575             while True:
# --> 576                 chunk_left = self._get_chunk_left()
#     577                 if chunk_left is None:
#     578                     return total_bytes
#
# ~/anaconda3/lib/python3.7/http/client.py in _get_chunk_left(self)
#     542                 self._safe_read(2)  # toss the CRLF at the end of the chunk
#     543             try:
# --> 544                 chunk_left = self._read_next_chunk_size()
#     545             except ValueError:
#     546                 raise IncompleteRead(b'')
#
# ~/anaconda3/lib/python3.7/http/client.py in _read_next_chunk_size(self)
#     502     def _read_next_chunk_size(self):
#     503         # Read the next chunk size from the file
# --> 504         line = self.fp.readline(_MAXLINE + 1)
#     505         if len(line) > _MAXLINE:
#     506             raise LineTooLong("chunk size")
#
# ~/anaconda3/lib/python3.7/socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# ~/anaconda3/lib/python3.7/site-packages/urllib3/contrib/pyopenssl.py in recv_into(self, *args, **kwargs)
#     307                 raise
#     308         except OpenSSL.SSL.WantReadError:
# --> 309             if not util.wait_for_read(self.socket, self.socket.gettimeout()):
#     310                 raise timeout('The read operation timed out')
#     311             else:
#
# ~/anaconda3/lib/python3.7/site-packages/urllib3/util/wait.py in wait_for_read(sock, timeout)
#     141     Returns True if the socket is readable, or False if the timeout expired.
#     142     """
# --> 143     return wait_for_socket(sock, read=True, timeout=timeout)
#     144
#     145
#
# ~/anaconda3/lib/python3.7/site-packages/urllib3/util/wait.py in poll_wait_for_socket(sock, read, write, timeout)
#     102         return poll_obj.poll(t)
#     103
# --> 104     return bool(_retry_on_intr(do_poll, timeout))
#     105
#     106
#
# ~/anaconda3/lib/python3.7/site-packages/urllib3/util/wait.py in _retry_on_intr(fn, timeout)
#      40     # Modern Python, that retries syscalls by default
#      41     def _retry_on_intr(fn, timeout):
# ---> 42         return fn(timeout)
#      43 else:
#      44     # Old and broken Pythons.
#
# ~/anaconda3/lib/python3.7/site-packages/urllib3/util/wait.py in do_poll(t)
#     100         if t is not None:
#     101             t *= 1000
# --> 102         return poll_obj.poll(t)
#     103
#     104     return bool(_retry_on_intr(do_poll, timeout))
#
# KeyboardInterrupt:

# %%
mydb.close()
